# %%
import matplotlib.pyplot as plt
import pandas as p
import seaborn as sns
import numpy as np
# %matplotlib inline
from scipy.stats import linregress
from scipy.spatial import distance
from matplotlib import colors
import scipy
import os
import copy
from matplotlib.backends.backend_pdf import PdfPages
# from sklearn.decomposition import PCA
from ast import literal_eval
# sns.set()
# sns.set_context('talk')
# sns.set(font="Avenir")
sns.set_color_codes()
sns.set_style('white')
sns.set_style('ticks')
# sns.set_style({'font.family': 'Avenir'})

# %%
def flatten(t):
    return [item for sublist in t for item in sublist]

# %%
f_list = ['F' + str(f) for f in range(201,213)] # inline forward primers
r_list = ['R' + str(r) for r in range(301,309)] # inline reverse primers 
n_list = ['N' + str(n) for n in [716,718,719,720,721,722,723,724,726,727,728,729]] # nextera n primers
s_list = ['S' + str(s) for s in [513,515,516,517,518,520,521,522]] # nextera s primers

prefixes = ['070418_diagonal','080618_Nextseq','082818_Hiseq']

write_loc = 'SequenceToCount/index_hopping/'

# %%
for prefix in prefixes:
    ### CREATE SBATCH FILE!!!
            
    sbatch_name = f'iHop_{prefix}_demultiplex.sbatch'
    
    with open(f'{write_loc}{sbatch_name}','w') as sbatch_f:
                
        sbatch_f.write(f"""#!/usr/bin/env bash
#SBATCH -J {sbatch_name}
#SBATCH -p hns,dpetrov,normal,owners
#SBATCH -n 16
#SBATCH -N 1
#SBATCH -t 2-00:00
#SBATCH --array=1-96
#SBATCH --mem-per-cpu=2G
#SBATCH --requeue
#SBATCH -o SlurmFiles/slurm-%A_%a_%x.out
#SBATCH --mail-user=grantkinsler@gmail.com
#SBATCH --mail-type=END

sample_sheets=$(sed -n "$SLURM_ARRAY_TASK_ID"p iHop_{prefix}_demultiplex.inp)

module load python/3.6.1
module load biology
module load ncbi-blast+/2.7.1
python3 /home/groups/dpetrov/SOFTWARE/BarcodeCounter2-master_07272021update/barcodeCounter.py -fastqDir ../AllRawData/ -outputDir ../BarcodeCounts_index_hopping/{prefix}/ -templateSeq ../Template_doubleBC_Read1First.txt -sample $sample_sheets -multiBCFasta ../Primers_noP.fasta -pairedEnd -useUMI -numThreads 16 -demultiplexOnly -useBowtie2 -bowtie2Path /home/groups/dpetrov/SOFTWARE/bowtie2-2.2.6_new/ -readLength 108
""")
        
    sbatch_name = f'iHop_{prefix}_map_barcodes.sbatch' 
        
    with open(f'{write_loc}{sbatch_name}','w') as sbatch_f:
                
        sbatch_f.write(f"""#!/usr/bin/env bash
#SBATCH -J {sbatch_name}
#SBATCH -p hns,dpetrov,normal,owners
#SBATCH -n 16
#SBATCH -N 1
#SBATCH -t 2-00:00
#SBATCH --array=1-1
#SBATCH --mem-per-cpu=2G
#SBATCH --requeue
#SBATCH -o SlurmFiles/slurm-%A_%a_%x.out
#SBATCH --mail-user=grantkinsler@gmail.com
#SBATCH --mail-type=END

module load python/3.6.1
module load biology
module load ncbi-blast+/2.7.1
python3 /home/groups/dpetrov/SOFTWARE/BarcodeCounter2-master_07272021update/barcodeCounter.py -fastqDir ../AllRawData/ -outputDir ../BarcodeCounts_index_hopping/{prefix}/ -templateSeq ../Template_doubleBC_Read1First.txt -sample iHop_{prefix}_All_Samples.txt -multiBCFasta ../Primers_noP.fasta -pairedEnd -useUMI -numThreads 16 -skipSplitFastq -barcodeList ../500pool_noconstant_bothBCs_withSpikeIns.fasta -useBowtie2 -bowtie2Path /home/groups/dpetrov/SOFTWARE/bowtie2-2.2.6_new/ -readLength 108 -remapBarcodes
""")
        
    with open(f'{write_loc}iHop_{prefix}_demultiplex.inp','w') as inp_f:
    
    
        for n in n_list:
            for s in s_list:
                            
                sample_list_name =  f'iHop_{prefix}_{n}{s}_Samples.txt'
                
                inp_f.write(f'{sample_list_name}\n')

    
    for n in n_list:
        for s in s_list:
            
            fastq_name = f'{prefix}_{n}{s}'
            
            sample_list_name =  f'iHop_{prefix}_{n}{s}_Samples.txt'
       
            
            with open(f'{write_loc}{sample_list_name}','w') as sample_f:        

                for f in f_list:
                    for r in r_list:
                        
                        sample_name = f'{n}_{s}_{f}_{r}'
                                    
                        sample_f.write(f'{sample_name}\t{fastq_name}\t{f}\t{r}\n')
    
#     
    all_sample_list_name =  f'iHop_{prefix}_All_Samples.txt'
    
    with open(f'{write_loc}{all_sample_list_name}','w') as all_sample_f:   
        for n in n_list:
            for s in s_list:

                fastq_name = f'{prefix}_{n}{s}'    

                for f in f_list:
                    for r in r_list:

                        sample_name = f'{n}_{s}_{f}_{r}'

                        all_sample_f.write(f'{sample_name}\t{fastq_name}\t{f}\t{r}\n')

# %%
n_list = ['N' + str(n) for n in [716,718,719,720,721,722,723,724,726,727,728,729]] # nextera n primers
s_list = ['S' + str(s) for s in [513,515,516,517,518,520,521,522]] # nextera s primers

# %%
samples = p.read_csv('SequenceToCount/All_Samples.txt',sep='\t',header=None)
samples.columns = ['sample','lane','f_primer','r_primer']

# %%
samples['sample'].values
# Out:
# array(['3-0', '3-1-1', '3-1-2', '3-1-3', '3-2-1', '3-2-2', '3-2-3',
#        '3-3-1', '3-3-2', '3-3-3', '3-4-1', '3-4-2', '3-4-3', '6-0',
#        '6-1-1', '6-1-2', '6-1-3', '6-2-1', '6-2-2', '6-2-3', '6-3-1',
#        '6-3-2', '6-3-3', '6-4-1', '6-4-2', '6-4-3', '13-0', '13-0_pool',
#        '13-1-1', '13-1-2', '13-1-3', '13-2-1', '13-2-2', '13-2-3',
#        '13-3-1', '13-3-2', '13-3-3', '13-4-1', '13-4-2', '13-4-3',
#        '18-1-1', '18-1-2', '18-1-3', '18-2-1', '18-2-2', '18-2-3',
#        '18-3-1', '18-3-2', '18-3-3', '18-4-1', '18-4-2', '18-4-3',
#        '20-1-1', '20-1-2', '20-1-3', '20-2-1', '20-2-2', '20-2-3',
#        '20-3-1', '20-3-2', '20-3-3', '20-4-1', '20-4-2', '20-4-3',
#        '21-0-1', '21-0-2', '21-0-4', '21-1-1', '21-1-2', '21-1-3',
#        '21-2-1', '21-2-2', '21-2-3', '21-3-1', '21-3-2', '21-3-3',
#        '21-4-1', '21-4-2', '21-4-3', '21+wt', '23-0', '23-1-1', '23-1-2',
#        '23-1-3', '23-2-1', '23-2-2', '23-2-3', '23-3-1', '23-3-2',
#        '23-3-3', '23-4-1', '23-4-2', '23-4-3', 'EE0-DE1-PCRa',
#        'EE0-DE1-PCRa', 'EE0-DE1-PCRa', 'EE0-DE1-PCRa', 'EE1-DE1-PCRa',
#        'EE1-DE1-PCRa', 'EE1-DE1-PCRa', 'EE1-DE1-PCRa', 'EE2-DE1-PCRa',
#        'EE2-DE1-PCRa', 'EE2-DE1-PCRa', 'EE2-DE1-PCRa', 'EE3-DE1-PCRa',
#        'EE3-DE1-PCRa', 'EE3-DE1-PCRa', 'EE3-DE1-PCRa', 'EE4-DE1-PCRa',
#        'EE4-DE1-PCRa', 'EE4-DE1-PCRa', 'EE4-DE1-PCRa', 'FF0-DE1-PCRa',
#        'FF0-DE1-PCRa', 'FF0-DE1-PCRa', 'FF0-DE1-PCRa', 'FF1-DE1-PCRa',
#        'FF1-DE1-PCRa', 'FF1-DE1-PCRa', 'FF1-DE1-PCRa', 'FF2-DE1-PCRa',
#        'FF2-DE1-PCRa', 'FF2-DE1-PCRa', 'FF2-DE1-PCRa', 'FF3-DE1-PCRa',
#        'FF3-DE1-PCRa', 'FF3-DE1-PCRa', 'FF3-DE1-PCRa', 'FF4-DE1-PCRa',
#        'FF4-DE1-PCRa', 'FF4-DE1-PCRa', 'FF4-DE1-PCRa', 'M0-DE1-PCRa',
#        'M0-DE1-PCRa', 'M0-DE1-PCRa', 'M0-DE1-PCRa', 'M1-DE1-PCRa',
#        'M1-DE1-PCRa', 'M1-DE1-PCRa', 'M1-DE1-PCRa', 'M2-DE1-PCRa',
#        'M2-DE1-PCRa', 'M2-DE1-PCRa', 'M2-DE1-PCRa', 'M3-DE1-PCRa',
#        'M3-DE1-PCRa', 'M3-DE1-PCRa', 'M3-DE1-PCRa', 'M4-DE1-PCRa',
#        'M4-DE1-PCRa', 'M4-DE1-PCRa', 'M4-DE1-PCRa', 'N0-DE1-PCRa',
#        'N0-DE1-PCRa', 'N0-DE1-PCRa', 'N0-DE1-PCRa', 'N1-DE1-PCRa',
#        'N1-DE1-PCRa', 'N1-DE1-PCRa', 'N1-DE1-PCRa', 'N2-DE1-PCRa',
#        'N2-DE1-PCRa', 'N2-DE1-PCRa', 'N2-DE1-PCRa', 'N3-DE1-PCRa',
#        'N3-DE1-PCRa', 'N3-DE1-PCRa', 'N3-DE1-PCRa', 'N4-DE1-PCRa',
#        'N4-DE1-PCRa', 'N4-DE1-PCRa', 'N4-DE1-PCRa', 'Q0-DE1-PCRa',
#        'Q0-DE1-PCRa', 'Q0-DE1-PCRa', 'Q0-DE1-PCRa', 'Q1-DE1-PCRa',
#        'Q1-DE1-PCRa', 'Q1-DE1-PCRa', 'Q1-DE1-PCRa', 'Q2-DE1-PCRa',
#        'Q2-DE1-PCRa', 'Q2-DE1-PCRa', 'Q2-DE1-PCRa', 'Q3-DE1-PCRa',
#        'Q3-DE1-PCRa', 'Q3-DE1-PCRa', 'Q3-DE1-PCRa', 'Q4-DE1-PCRa',
#        'Q4-DE1-PCRa', 'Q4-DE1-PCRa', 'Q4-DE1-PCRa', 'R0-DE1-PCRa',
#        'R0-DE1-PCRa', 'R0-DE1-PCRa', 'R0-DE1-PCRa', 'R1-DE1-PCRa',
#        'R1-DE1-PCRa', 'R1-DE1-PCRa', 'R1-DE1-PCRa', 'R2-DE1-PCRa',
#        'R2-DE1-PCRa', 'R2-DE1-PCRa', 'R2-DE1-PCRa', 'R3-DE1-PCRa',
#        'R3-DE1-PCRa', 'R3-DE1-PCRa', 'R3-DE1-PCRa', 'R4-DE1-PCRa',
#        'R4-DE1-PCRa', 'R4-DE1-PCRa', 'R4-DE1-PCRa', 'S0-DE1-PCRa',
#        'S0-DE1-PCRa', 'S0-DE1-PCRa', 'S0-DE1-PCRa', 'S1-DE1-PCRa',
#        'S1-DE1-PCRa', 'S1-DE1-PCRa', 'S1-DE1-PCRa', 'S2-DE1-PCRa',
#        'S2-DE1-PCRa', 'S2-DE1-PCRa', 'S2-DE1-PCRa', 'S3-DE1-PCRa',
#        'S3-DE1-PCRa', 'S3-DE1-PCRa', 'S3-DE1-PCRa', 'S4-DE1-PCRa',
#        'S4-DE1-PCRa', 'S4-DE1-PCRa', 'S4-DE1-PCRa', 'T0-DE1-PCRa',
#        'T0-DE1-PCRa', 'T0-DE1-PCRa', 'T0-DE1-PCRa', 'T1-DE1-PCRa',
#        'T1-DE1-PCRa', 'T1-DE1-PCRa', 'T1-DE1-PCRa', 'T2-DE1-PCRa',
#        'T2-DE1-PCRa', 'T2-DE1-PCRa', 'T2-DE1-PCRa', 'T3-DE1-PCRa',
#        'T3-DE1-PCRa', 'T3-DE1-PCRa', 'T3-DE1-PCRa', 'T4-DE1-PCRa',
#        'T4-DE1-PCRa', 'T4-DE1-PCRa', 'T4-DE1-PCRa', 'U0-DE1-PCRa',
#        'U0-DE1-PCRa', 'U0-DE1-PCRa', 'U0-DE1-PCRa', 'U1-DE1-PCRa',
#        'U1-DE1-PCRa', 'U1-DE1-PCRa', 'U1-DE1-PCRa', 'U2-DE1-PCRa',
#        'U2-DE1-PCRa', 'U2-DE1-PCRa', 'U2-DE1-PCRa', 'U3-DE1-PCRa',
#        'U3-DE1-PCRa', 'U3-DE1-PCRa', 'U3-DE1-PCRa', 'U4-DE1-PCRa',
#        'U4-DE1-PCRa', 'U4-DE1-PCRa', 'U4-DE1-PCRa', 'V0-DE1-PCRa',
#        'V0-DE1-PCRa', 'V0-DE1-PCRa', 'V0-DE1-PCRa', 'V1-DE1-PCRa',
#        'V1-DE1-PCRa', 'V1-DE1-PCRa', 'V1-DE1-PCRa', 'V2-DE1-PCRa',
#        'V2-DE1-PCRa', 'V2-DE1-PCRa', 'V2-DE1-PCRa', 'V3-DE1-PCRa',
#        'V3-DE1-PCRa', 'V3-DE1-PCRa', 'V3-DE1-PCRa', 'V4-DE1-PCRa',
#        'V4-DE1-PCRa', 'V4-DE1-PCRa', 'V4-DE1-PCRa', 'W0-DE1-PCRa',
#        'W0-DE1-PCRa', 'W0-DE1-PCRa', 'W0-DE1-PCRa', 'W1-DE1-PCRa',
#        'W1-DE1-PCRa', 'W1-DE1-PCRa', 'W1-DE1-PCRa', 'W2-DE1-PCRa',
#        'W2-DE1-PCRa', 'W2-DE1-PCRa', 'W2-DE1-PCRa', 'W3-DE1-PCRa',
#        'W3-DE1-PCRa', 'W3-DE1-PCRa', 'W3-DE1-PCRa', 'W4-DE1-PCRa',
#        'W4-DE1-PCRa', 'W4-DE1-PCRa', 'W4-DE1-PCRa', 'X0-DE1-PCRa',
#        'X0-DE1-PCRa', 'X0-DE1-PCRa', 'X0-DE1-PCRa', 'X1-DE1-PCRa',
#        'X1-DE1-PCRa', 'X1-DE1-PCRa', 'X1-DE1-PCRa', 'X2-DE1-PCRa',
#        'X2-DE1-PCRa', 'X2-DE1-PCRa', 'X2-DE1-PCRa', 'X3-DE1-PCRa',
#        'X3-DE1-PCRa', 'X3-DE1-PCRa', 'X3-DE1-PCRa', 'X4-DE1-PCRa',
#        'X4-DE1-PCRa', 'X4-DE1-PCRa', 'X4-DE1-PCRa', 'A0-DE1-PCRa',
#        'A0-DE1-PCRa', 'A0-DE1-PCRb', 'A0-DE1-PCRb', 'A1-DE1-PCRa',
#        'A1-DE1-PCRa', 'A2-DE1-PCRa', 'A2-DE1-PCRa', 'A3-DE1-PCRa',
#        'A3-DE1-PCRa', 'A4-DE1-PCRa', 'A4-DE1-PCRa', 'AA0-DE1-PCRa',
#        'AA0-DE1-PCRa', 'AA1-DE1-PCRa', 'AA1-DE1-PCRa', 'AA2-DE1-PCRa',
#        'AA2-DE1-PCRa', 'AA2-DE1-PCRa', 'AA3-DE1-PCRa', 'AA3-DE1-PCRa',
#        'AA4-DE1-PCRa', 'AA4-DE1-PCRa', 'BB0-DE1-PCRa', 'BB0-DE1-PCRa',
#        'BB1-DE1-PCRa', 'BB1-DE1-PCRa', 'BB2-DE1-PCRa', 'BB2-DE1-PCRa',
#        'BB3-DE1-PCRa', 'BB3-DE1-PCRa', 'BB4-DE1-PCRa', 'BB4-DE1-PCRa',
#        'CC0-DE1-PCRa', 'CC0-DE1-PCRa', 'CC1-DE1-PCRa', 'CC1-DE1-PCRa',
#        'CC2-DE1-PCRa', 'CC2-DE1-PCRa', 'CC3-DE1-PCRa', 'CC3-DE1-PCRa',
#        'CC4-DE1-PCRa', 'CC4-DE1-PCRa', 'D0-DE1-PCRa', 'D0-DE1-PCRa',
#        'D0-DE1-PCRb', 'D0-DE1-PCRb', 'D1-DE1-PCRa', 'D1-DE1-PCRa',
#        'D2-DE1-PCRa', 'D2-DE1-PCRa', 'D3-DE1-PCRa', 'D3-DE1-PCRa',
#        'D4-DE1-PCRa', 'D4-DE1-PCRa', 'DD0-DE1-PCRa', 'DD0-DE1-PCRa',
#        'DD1-DE1-PCRa', 'DD1-DE1-PCRa', 'DD2-DE1-PCRa', 'DD2-DE1-PCRa',
#        'DD3-DE1-PCRa', 'DD3-DE1-PCRa', 'DD4-DE1-PCRa', 'DD4-DE1-PCRa',
#        'E0-DE1-PCRa', 'E0-DE1-PCRa', 'E0-DE1-PCRb', 'E0-DE1-PCRb',
#        'E0-DE1-PCRb', 'E1-DE1-PCRa', 'E1-DE1-PCRa', 'E1-DE1-PCRa',
#        'E2-DE1-PCRa', 'E2-DE1-PCRa', 'E3-DE1-PCRa', 'E3-DE1-PCRa',
#        'E4-DE1-PCRa', 'E4-DE1-PCRa', 'F0-DE1-PCRa', 'F0-DE1-PCRa',
#        'F0-DE1-PCRb', 'F0-DE1-PCRb', 'F1-DE1-PCRa', 'F1-DE1-PCRa',
#        'F2-DE1-PCRa', 'F2-DE1-PCRa', 'F3-DE1-PCRa', 'F3-DE1-PCRa',
#        'F4-DE1-PCRa', 'F4-DE1-PCRa', 'G0-DE1-PCRa', 'G0-DE1-PCRa',
#        'G0-DE1-PCRb', 'G0-DE1-PCRb', 'G1-DE1-PCRa', 'G1-DE1-PCRa',
#        'G2-DE1-PCRa', 'G2-DE1-PCRa', 'G3-DE1-PCRa', 'G3-DE1-PCRa',
#        'G4-DE1-PCRa', 'G4-DE1-PCRa', 'G4-DE1-PCRa', 'GG0-DE1-PCRa',
#        'GG0-DE1-PCRa', 'GG1-DE1-PCRa', 'GG1-DE1-PCRa', 'GG1-DE1-PCRa',
#        'GG2-DE1-PCRa', 'GG2-DE1-PCRa', 'GG3-DE1-PCRa', 'GG3-DE1-PCRa',
#        'GG4-DE1-PCRa', 'GG4-DE1-PCRa', 'H0-DE1-PCRa', 'H0-DE1-PCRa',
#        'H0-DE1-PCRb', 'H0-DE1-PCRb', 'H1-DE1-PCRa', 'H1-DE1-PCRa',
#        'H2-DE1-PCRa', 'H2-DE1-PCRa', 'H3-DE1-PCRa', 'H3-DE1-PCRa',
#        'H4-DE1-PCRa', 'H4-DE1-PCRa', 'I0-DE1-PCRa', 'I0-DE1-PCRa',
#        'I1-DE1-PCRa', 'I1-DE1-PCRa', 'I2-DE1-PCRa', 'I2-DE1-PCRa',
#        'I3-DE1-PCRa', 'I3-DE1-PCRa', 'I4-DE1-PCRa', 'I4-DE1-PCRa',
#        'J0-DE1-PCRa', 'J0-DE1-PCRa', 'J0-DE1-PCRb', 'J0-DE1-PCRb',
#        'J1-DE1-PCRa', 'J1-DE1-PCRa', 'J2-DE1-PCRa', 'J2-DE1-PCRa',
#        'J3-DE1-PCRa', 'J3-DE1-PCRa', 'J4-DE1-PCRa', 'J4-DE1-PCRa',
#        'K0-DE1-PCRa', 'K0-DE1-PCRa', 'K0-DE1-PCRb', 'K0-DE1-PCRb',
#        'K1-DE1-PCRa', 'K1-DE1-PCRa', 'K2-DE1-PCRa', 'K2-DE1-PCRa',
#        'K3-DE1-PCRa', 'K3-DE1-PCRa', 'K3-DE1-PCRa', 'K4-DE1-PCRa',
#        'K4-DE1-PCRa', 'L0-DE1-PCRa', 'L0-DE1-PCRa', 'L1-DE1-PCRa',
#        'L1-DE1-PCRa', 'L2-DE1-PCRa', 'L2-DE1-PCRa', 'L3-DE1-PCRa',
#        'L3-DE1-PCRa', 'L4-DE1-PCRa', 'L4-DE1-PCRa', 'O0-DE1-PCRa',
#        'O0-DE1-PCRa', 'O1-DE1-PCRa', 'O1-DE1-PCRa', 'O2-DE1-PCRa',
#        'O2-DE1-PCRa', 'O3-DE1-PCRa', 'O3-DE1-PCRa', 'O4-DE1-PCRa',
#        'O4-DE1-PCRa', 'P0-DE1-PCRa', 'P0-DE1-PCRa', 'P1-DE1-PCRa',
#        'P1-DE1-PCRa', 'P1-DE1-PCRa', 'P2-DE1-PCRa', 'P2-DE1-PCRa',
#        'P3-DE1-PCRa', 'P3-DE1-PCRa', 'P4-DE1-PCRa', 'P4-DE1-PCRa',
#        'B0-DE1-PCRa', 'B0-DE1-PCRa', 'B0-DE2-PCRa', 'B0-DE2-PCRa',
#        'B0-DE2-PCRb', 'B0-DE2-PCRc', 'B0-DE3-PCRa', 'B0-DE4-PCRa',
#        'B1-DE1-PCRa', 'B2-DE1-PCRa', 'B2-DE1-PCRa', 'B2-DE1-PCRb',
#        'B2-DE2-PCRa', 'B2-DE3-PCRa', 'B2-DE4-PCRa', 'B3-DE1-PCRb',
#        'B4-DE1-PCRa', 'B4-DE1-PCRa', 'B4-DE2-PCRa', 'B4-DE2-PCRa',
#        'B4-DE2-PCRb', 'B4-DE3-PCRa', 'B4-DE4-PCRa', 'C0-DE1-PCRa',
#        'C0-DE1-PCRb', 'C0-DE2-PCRa', 'C1-DE1-PCRb', 'C2-DE1-PCRa',
#        'C2-DE2-PCRa', 'C3-DE1-PCRa', 'C4-DE1-PCRa', 'C4-DE2-PCRa',
#        'Tneg-DE1-PCRa', 'Tneg-DE2-PCRa', 'Y0-DE1-PCRa', 'Y0-DE2-PCRa',
#        'Y0-DE2-PCRb', 'Y0-DE3-PCRa', 'Y0-DE4-PCRa', 'Y1-DE1-PCRb',
#        'Y2-DE1-PCRa', 'Y2-DE1-PCRa', 'Y2-DE1-PCRb', 'Y2-DE2-PCRa',
#        'Y2-DE3-PCRa', 'Y2-DE4-PCRa', 'Y3-DE1-PCRa', 'Y3-DE1-PCRa',
#        'Y4-DE1-PCRa', 'Y4-DE1-PCRb', 'Y4-DE2-PCRa', 'Y4-DE3-PCRa',
#        'Y4-DE4-PCRa', 'Z0-DE1-PCRa', 'Z0-DE2-PCRa', 'Z1-DE1-PCRa',
#        'Z2-DE1-PCRa', 'Z2-DE1-PCRb', 'Z2-DE2-PCRa', 'Z3-DE1-PCRa',
#        'Z4-DE1-PCRa', 'Z4-DE2-PCRa', 'A0-DE2-PCRa', 'A4-DE1-PCRb',
#        'B2-DE1-PCRc', 'C0-DE1-PCRc', 'D1-DE1-PCRb', 'E0-DE2-PCRa',
#        'E4-DE1-PCRb', 'F3-DE1-PCRb', 'A1-DE1-PCRb', 'B3-DE1-PCRc',
#        'C2-DE3-PCRb', 'D2-DE1-PCRb', 'E1-DE2-PCRa', 'F0-DE2-PCRa',
#        'F4-DE1-PCRb', 'Tneg-DE3-PCRa', 'A2-DE1-PCRb', 'B1-DE2-PCRa',
#        'B4-DE5-PCRa', 'C2-DE3-PCRa', 'C3-DE2-PCRa', 'D3-DE1-PCRb',
#        'E2-DE1-PCRb', 'F1-DE1-PCRb', 'A3-DE1-PCRb', 'C1-DE1-PCRc',
#        'C4-DE3-PCRa', 'C4-DE3-PCRb', 'D0-DE2-PCRa', 'D4-DE1-PCRb',
#        'E3-DE1-PCRb', 'F2-DE1-PCRb', 'B3-DE1-PCRa', 'B3-DE1-PCRa',
#        'B3-DE1-PCRa', 'B3-DE1-PCRa', 'B3-DE1-PCRa', 'C1-DE1-PCRa',
#        'C1-DE1-PCRa', 'C1-DE1-PCRa', 'Y1-DE1-PCRa', 'Y1-DE1-PCRa',
#        'Y1-DE1-PCRa', '1.4%-T0', '1.4%-R1-T1', '1.4%-R1-T2', '1.4%-R1-T3',
#        '1.4%-R1-T4', '1.4%-R2-T1', '1.4%-R2-T2', '1.4%-R2-T3',
#        '1.4%-R2-T4', '1.5%-T0', '1.5%-R1-T1', '1.5%-R1-T2', '1.5%-R1-T3',
#        '1.5%-R1-T4', '1.5%-R2-T1', '1.5%-R2-T2', '1.5%-R2-T3',
#        '1.5%-R2-T4', '1.6%-T0', '1.6%-R1-T1', '1.6%-R1-T2', '1.6%-R1-T3',
#        '1.6%-R1-T4', '1.6%-R2-T1', '1.6%-R2-T2', '1.6%-R2-T3',
#        '1.6%-R2-T4', '1.7%-T0', '1.7%-R1-T1', '1.7%-R1-T2', '1.7%-R1-T3',
#        '1.7%-R1-T4', '1.7%-R2-T1', '1.7%-R2-T2', '1.7%-R2-T3',
#        '1.7%-R2-T4', '1.8%-T0', '1.8%-R1-T1', '1.8%-R1-T2', '1.8%-R1-T3',
#        '1.8%-R1-T4', '1.8%-R2-T1', '1.8%-R2-T2', '1.8%-R2-T3',
#        '1.8%-R2-T4', '2.5%-T0', '2.5%-R1-T1', '2.5%-R1-T2', '2.5%-R1-T3',
#        '2.5%-R1-T4', '2.5%-R2-T1', '2.5%-R2-T2', '2.5%-R2-T3',
#        '2.5%-R2-T4', 'Ben0.4-T0', 'Ben0.4-R1-T1', 'Ben0.4-R1-T2',
#        'Ben0.4-R1-T3', 'Ben0.4-R1-T4', 'Ben0.4-R2-T1', 'Ben0.4-R2-T2',
#        'Ben0.4-R2-T3', 'Ben0.4-R2-T4', 'Ben2-T0', 'Ben2-R1-T1',
#        'Ben2-R1-T2', 'Ben2-R1-T3', 'Ben2-R1-T4', 'Ben2-R2-T1',
#        'Ben2-R2-T2', 'Ben2-R2-T3', 'Ben2-R2-T4', 'Ben10-T0',
#        'Ben10-R1-T1', 'Ben10-R1-T2', 'Ben10-R1-T3', 'Ben10-R1-T4',
#        'Ben10-R2-T1', 'Ben10-R2-T2', 'Ben10-R2-T3', 'Ben10-R2-T4'],
#       dtype=object)

# %%
samples
# Out:
#            sample                       lane f_primer r_primer
# 0             3-0  Experiment1and3_Unindexed     F204     R301
# 1           3-1-1  Experiment1and3_Unindexed     F203     R302
# 2           3-1-2  Experiment1and3_Unindexed     F204     R302
# 3           3-1-3  Experiment1and3_Unindexed     F202     R305
# 4           3-2-1  Experiment1and3_Unindexed     F206     R301
# 5           3-2-2  Experiment1and3_Unindexed     F204     R305
# 6           3-2-3  Experiment1and3_Unindexed     F205     R305
# 7           3-3-1  Experiment1and3_Unindexed     F206     R305
# 8           3-3-2  Experiment1and3_Unindexed     F207     R305
# 9           3-3-3  Experiment1and3_Unindexed     F201     R306
# 10          3-4-1  Experiment1and3_Unindexed     F202     R306
# 11          3-4-2  Experiment1and3_Unindexed     F203     R306
# 12          3-4-3  Experiment1and3_Unindexed     F204     R306
# 13            6-0    Experiment6-8_Unindexed     F206     R304
# 14          6-1-1    Experiment6-8_Unindexed     F206     R305
# 15          6-1-2    Experiment6-8_Unindexed     F206     R306
# 16          6-1-3    Experiment6-8_Unindexed     F206     R307
# 17          6-2-1    Experiment6-8_Unindexed     F201     R301
# 18          6-2-2    Experiment6-8_Unindexed     F201     R302
# 19          6-2-3    Experiment6-8_Unindexed     F201     R303
# 20          6-3-1    Experiment6-8_Unindexed     F201     R304
# 21          6-3-2    Experiment6-8_Unindexed     F201     R305
# 22          6-3-3    Experiment6-8_Unindexed     F201     R306
# 23          6-4-1    Experiment6-8_Unindexed     F201     R307
# 24          6-4-2    Experiment6-8_Unindexed     F202     R301
# 25          6-4-3    Experiment6-8_Unindexed     F202     R302
# 26           13-0  Experiment13-15_Unindexed     F201     R301
# 27      13-0_pool  Experiment13-15_Unindexed     F201     R302
# 28         13-1-1  Experiment13-15_Unindexed     F201     R303
# 29         13-1-2  Experiment13-15_Unindexed     F201     R304
# ..            ...                        ...      ...      ...
# 682    2.5%-R2-T2     090519_HiSeqX_N723S520     F207     R306
# 683    2.5%-R2-T3     090519_HiSeqX_N724S520     F208     R306
# 684    2.5%-R2-T4     090519_HiSeqX_N726S520     F209     R306
# 685     Ben0.4-T0     090519_HiSeqX_N716S521     F201     R307
# 686  Ben0.4-R1-T1     090519_HiSeqX_N718S521     F202     R307
# 687  Ben0.4-R1-T2     090519_HiSeqX_N719S521     F203     R307
# 688  Ben0.4-R1-T3     090519_HiSeqX_N720S521     F204     R307
# 689  Ben0.4-R1-T4     090519_HiSeqX_N721S521     F205     R307
# 690  Ben0.4-R2-T1     090519_HiSeqX_N722S521     F206     R307
# 691  Ben0.4-R2-T2     090519_HiSeqX_N723S521     F207     R307
# 692  Ben0.4-R2-T3     090519_HiSeqX_N724S521     F208     R307
# 693  Ben0.4-R2-T4     090519_HiSeqX_N726S521     F209     R307
# 694       Ben2-T0     090519_HiSeqX_N716S522     F201     R308
# 695    Ben2-R1-T1     090519_HiSeqX_N718S522     F202     R308
# 696    Ben2-R1-T2     090519_HiSeqX_N719S522     F203     R308
# 697    Ben2-R1-T3     090519_HiSeqX_N720S522     F204     R308
# 698    Ben2-R1-T4     090519_HiSeqX_N721S522     F205     R308
# 699    Ben2-R2-T1     090519_HiSeqX_N722S522     F206     R308
# 700    Ben2-R2-T2     090519_HiSeqX_N723S522     F207     R308
# 701    Ben2-R2-T3     090519_HiSeqX_N724S522     F208     R308
# 702    Ben2-R2-T4     090519_HiSeqX_N726S522     F209     R308
# 703      Ben10-T0     090519_HiSeqX_N727S513     F210     R301
# 704   Ben10-R1-T1     090519_HiSeqX_N727S515     F210     R302
# 705   Ben10-R1-T2     090519_HiSeqX_N727S516     F210     R303
# 706   Ben10-R1-T3     090519_HiSeqX_N727S517     F210     R304
# 707   Ben10-R1-T4     090519_HiSeqX_N727S518     F210     R305
# 708   Ben10-R2-T1     090519_HiSeqX_N728S515     F211     R302
# 709   Ben10-R2-T2     090519_HiSeqX_N728S516     F211     R303
# 710   Ben10-R2-T3     090519_HiSeqX_N728S517     F211     R304
# 711   Ben10-R2-T4     090519_HiSeqX_N728S518     F211     R305
#
# [712 rows x 4 columns]

# %%
groups = {}

# First assign each entry to a group
for g,lane in enumerate(np.unique(samples['lane'].values)):
    groups[g] = samples[samples['lane']==lane]['sample'].values

# %%
groups
# Out:
# {0: array(['B0-DE1-PCRa', 'B0-DE2-PCRa', 'B2-DE1-PCRa', 'B4-DE1-PCRa',
#         'B4-DE2-PCRa', 'Y2-DE1-PCRa', 'Y3-DE1-PCRa', 'B3-DE1-PCRa'],
#        dtype=object),
#  1: array(['B0-DE1-PCRa', 'B0-DE2-PCRa', 'B0-DE2-PCRb', 'B0-DE2-PCRc',
#         'B0-DE3-PCRa', 'B0-DE4-PCRa', 'B1-DE1-PCRa', 'B2-DE1-PCRa',
#         'B2-DE1-PCRb', 'B2-DE2-PCRa', 'B2-DE3-PCRa', 'B2-DE4-PCRa',
#         'B3-DE1-PCRb', 'B4-DE1-PCRa', 'B4-DE2-PCRa', 'B4-DE2-PCRb',
#         'B4-DE3-PCRa', 'B4-DE4-PCRa', 'C0-DE1-PCRa', 'C0-DE1-PCRb',
#         'C0-DE2-PCRa', 'C1-DE1-PCRb', 'C2-DE1-PCRa', 'C2-DE2-PCRa',
#         'C3-DE1-PCRa', 'C4-DE1-PCRa', 'C4-DE2-PCRa', 'Tneg-DE1-PCRa',
#         'Tneg-DE2-PCRa', 'Y0-DE1-PCRa', 'Y0-DE2-PCRa', 'Y0-DE2-PCRb',
#         'Y0-DE3-PCRa', 'Y0-DE4-PCRa', 'Y1-DE1-PCRb', 'Y2-DE1-PCRa',
#         'Y2-DE1-PCRb', 'Y2-DE2-PCRa', 'Y2-DE3-PCRa', 'Y2-DE4-PCRa',
#         'Y3-DE1-PCRa', 'Y4-DE1-PCRa', 'Y4-DE1-PCRb', 'Y4-DE2-PCRa',
#         'Y4-DE3-PCRa', 'Y4-DE4-PCRa', 'Z0-DE1-PCRa', 'Z0-DE2-PCRa',
#         'Z1-DE1-PCRa', 'Z2-DE1-PCRa', 'Z2-DE1-PCRb', 'Z2-DE2-PCRa',
#         'Z3-DE1-PCRa', 'Z4-DE1-PCRa', 'Z4-DE2-PCRa', 'B3-DE1-PCRa',
#         'C1-DE1-PCRa', 'Y1-DE1-PCRa'], dtype=object),
#  2: array(['E0-DE1-PCRb'], dtype=object),
#  3: array(['E1-DE1-PCRa'], dtype=object),
#  4: array(['P1-DE1-PCRa'], dtype=object),
#  5: array(['GG1-DE1-PCRa'], dtype=object),
#  6: array(['AA2-DE1-PCRa'], dtype=object),
#  7: array(['K3-DE1-PCRa'], dtype=object),
#  8: array(['G4-DE1-PCRa'], dtype=object),
#  9: array(['B3-DE1-PCRa'], dtype=object),
#  10: array(['A0-DE1-PCRb'], dtype=object),
#  11: array(['GG0-DE1-PCRa'], dtype=object),
#  12: array(['J1-DE1-PCRa'], dtype=object),
#  13: array(['A0-DE1-PCRa'], dtype=object),
#  14: array(['I2-DE1-PCRa'], dtype=object),
#  15: array(['D3-DE1-PCRa'], dtype=object),
#  16: array(['BB3-DE1-PCRa'], dtype=object),
#  17: array(['K4-DE1-PCRa'], dtype=object),
#  18: array(['D0-DE1-PCRb'], dtype=object),
#  19: array(['A1-DE1-PCRa'], dtype=object),
#  20: array(['K1-DE1-PCRa'], dtype=object),
#  21: array(['D0-DE1-PCRa'], dtype=object),
#  22: array(['J2-DE1-PCRa'], dtype=object),
#  23: array(['E3-DE1-PCRa'], dtype=object),
#  24: array(['CC3-DE1-PCRa'], dtype=object),
#  25: array(['L4-DE1-PCRa'], dtype=object),
#  26: array(['E0-DE1-PCRb'], dtype=object),
#  27: array(['D1-DE1-PCRa'], dtype=object),
#  28: array(['L1-DE1-PCRa'], dtype=object),
#  29: array(['E0-DE1-PCRa'], dtype=object),
#  30: array(['K2-DE1-PCRa'], dtype=object),
#  31: array(['F3-DE1-PCRa'], dtype=object),
#  32: array(['DD3-DE1-PCRa'], dtype=object),
#  33: array(['O4-DE1-PCRa'], dtype=object),
#  34: array(['F0-DE1-PCRb'], dtype=object),
#  35: array(['E1-DE1-PCRa'], dtype=object),
#  36: array(['O1-DE1-PCRa'], dtype=object),
#  37: array(['F0-DE1-PCRa'], dtype=object),
#  38: array(['L2-DE1-PCRa'], dtype=object),
#  39: array(['G3-DE1-PCRa'], dtype=object),
#  40: array(['GG3-DE1-PCRa'], dtype=object),
#  41: array(['P4-DE1-PCRa'], dtype=object),
#  42: array(['I0-DE1-PCRa'], dtype=object),
#  43: array(['G0-DE1-PCRa'], dtype=object),
#  44: array(['P1-DE1-PCRa'], dtype=object),
#  45: array(['DD1-DE1-PCRa'], dtype=object),
#  46: array(['O2-DE1-PCRa'], dtype=object),
#  47: array(['H3-DE1-PCRa'], dtype=object),
#  48: array(['A4-DE1-PCRa'], dtype=object),
#  49: array(['AA4-DE1-PCRa'], dtype=object),
#  50: array(['L0-DE1-PCRa'], dtype=object),
#  51: array(['H0-DE1-PCRa'], dtype=object),
#  52: array(['AA1-DE1-PCRa'], dtype=object),
#  53: array(['GG1-DE1-PCRa'], dtype=object),
#  54: array(['P2-DE1-PCRa'], dtype=object),
#  55: array(['I3-DE1-PCRa'], dtype=object),
#  56: array(['D4-DE1-PCRa'], dtype=object),
#  57: array(['BB4-DE1-PCRa'], dtype=object),
#  58: array(['O0-DE1-PCRa'], dtype=object),
#  59: array(['J0-DE1-PCRa'], dtype=object),
#  60: array(['BB1-DE1-PCRa'], dtype=object),
#  61: array(['A2-DE1-PCRa'], dtype=object),
#  62: array(['AA2-DE1-PCRa'], dtype=object),
#  63: array(['J3-DE1-PCRa'], dtype=object),
#  64: array(['E4-DE1-PCRa'], dtype=object),
#  65: array(['CC4-DE1-PCRa'], dtype=object),
#  66: array(['P0-DE1-PCRa'], dtype=object),
#  67: array(['K0-DE1-PCRa'], dtype=object),
#  68: array(['CC1-DE1-PCRa'], dtype=object),
#  69: array(['D2-DE1-PCRa'], dtype=object),
#  70: array(['BB2-DE1-PCRa'], dtype=object),
#  71: array(['K3-DE1-PCRa'], dtype=object),
#  72: array(['F4-DE1-PCRa'], dtype=object),
#  73: array(['DD4-DE1-PCRa'], dtype=object),
#  74: array(['AA0-DE1-PCRa'], dtype=object),
#  75: array(['F1-DE1-PCRa'], dtype=object),
#  76: array(['G0-DE1-PCRb'], dtype=object),
#  77: array(['E2-DE1-PCRa'], dtype=object),
#  78: array(['CC2-DE1-PCRa'], dtype=object),
#  79: array(['L3-DE1-PCRa'], dtype=object),
#  80: array(['G4-DE1-PCRa'], dtype=object),
#  81: array(['GG4-DE1-PCRa'], dtype=object),
#  82: array(['BB0-DE1-PCRa'], dtype=object),
#  83: array(['G1-DE1-PCRa'], dtype=object),
#  84: array(['H0-DE1-PCRb'], dtype=object),
#  85: array(['F2-DE1-PCRa'], dtype=object),
#  86: array(['DD2-DE1-PCRa'], dtype=object),
#  87: array(['O3-DE1-PCRa'], dtype=object),
#  88: array(['H4-DE1-PCRa'], dtype=object),
#  89: array(['B3-DE1-PCRa'], dtype=object),
#  90: array(['CC0-DE1-PCRa'], dtype=object),
#  91: array(['H1-DE1-PCRa'], dtype=object),
#  92: array(['J0-DE1-PCRb'], dtype=object),
#  93: array(['G2-DE1-PCRa'], dtype=object),
#  94: array(['GG2-DE1-PCRa'], dtype=object),
#  95: array(['P3-DE1-PCRa'], dtype=object),
#  96: array(['I4-DE1-PCRa'], dtype=object),
#  97: array(['C1-DE1-PCRa'], dtype=object),
#  98: array(['DD0-DE1-PCRa'], dtype=object),
#  99: array(['I1-DE1-PCRa'], dtype=object),
#  100: array(['K0-DE1-PCRb'], dtype=object),
#  101: array(['H2-DE1-PCRa'], dtype=object),
#  102: array(['A3-DE1-PCRa'], dtype=object),
#  103: array(['AA3-DE1-PCRa'], dtype=object),
#  104: array(['J4-DE1-PCRa'], dtype=object),
#  105: array(['Y1-DE1-PCRa'], dtype=object),
#  106: array(['A0-DE1-PCRb'], dtype=object),
#  107: array(['GG0-DE1-PCRa'], dtype=object),
#  108: array(['J1-DE1-PCRa'], dtype=object),
#  109: array(['A0-DE1-PCRa'], dtype=object),
#  110: array(['I2-DE1-PCRa'], dtype=object),
#  111: array(['D3-DE1-PCRa'], dtype=object),
#  112: array(['BB3-DE1-PCRa'], dtype=object),
#  113: array(['K4-DE1-PCRa'], dtype=object),
#  114: array(['D0-DE1-PCRb'], dtype=object),
#  115: array(['A1-DE1-PCRa'], dtype=object),
#  116: array(['K1-DE1-PCRa'], dtype=object),
#  117: array(['D0-DE1-PCRa'], dtype=object),
#  118: array(['J2-DE1-PCRa'], dtype=object),
#  119: array(['E3-DE1-PCRa'], dtype=object),
#  120: array(['CC3-DE1-PCRa'], dtype=object),
#  121: array(['L4-DE1-PCRa'], dtype=object),
#  122: array(['E0-DE1-PCRb'], dtype=object),
#  123: array(['D1-DE1-PCRa'], dtype=object),
#  124: array(['L1-DE1-PCRa'], dtype=object),
#  125: array(['E0-DE1-PCRa'], dtype=object),
#  126: array(['K2-DE1-PCRa'], dtype=object),
#  127: array(['F3-DE1-PCRa'], dtype=object),
#  128: array(['DD3-DE1-PCRa'], dtype=object),
#  129: array(['O4-DE1-PCRa'], dtype=object),
#  130: array(['F0-DE1-PCRb'], dtype=object),
#  131: array(['E1-DE1-PCRa'], dtype=object),
#  132: array(['O1-DE1-PCRa'], dtype=object),
#  133: array(['F0-DE1-PCRa'], dtype=object),
#  134: array(['L2-DE1-PCRa'], dtype=object),
#  135: array(['G3-DE1-PCRa'], dtype=object),
#  136: array(['GG3-DE1-PCRa'], dtype=object),
#  137: array(['P4-DE1-PCRa'], dtype=object),
#  138: array(['I0-DE1-PCRa'], dtype=object),
#  139: array(['G0-DE1-PCRa'], dtype=object),
#  140: array(['P1-DE1-PCRa'], dtype=object),
#  141: array(['DD1-DE1-PCRa'], dtype=object),
#  142: array(['O2-DE1-PCRa'], dtype=object),
#  143: array(['H3-DE1-PCRa'], dtype=object),
#  144: array(['A4-DE1-PCRa'], dtype=object),
#  145: array(['AA4-DE1-PCRa'], dtype=object),
#  146: array(['L0-DE1-PCRa'], dtype=object),
#  147: array(['H0-DE1-PCRa'], dtype=object),
#  148: array(['AA1-DE1-PCRa'], dtype=object),
#  149: array(['GG1-DE1-PCRa'], dtype=object),
#  150: array(['P2-DE1-PCRa'], dtype=object),
#  151: array(['I3-DE1-PCRa'], dtype=object),
#  152: array(['D4-DE1-PCRa'], dtype=object),
#  153: array(['BB4-DE1-PCRa'], dtype=object),
#  154: array(['O0-DE1-PCRa'], dtype=object),
#  155: array(['J0-DE1-PCRa'], dtype=object),
#  156: array(['BB1-DE1-PCRa'], dtype=object),
#  157: array(['A2-DE1-PCRa'], dtype=object),
#  158: array(['AA2-DE1-PCRa'], dtype=object),
#  159: array(['J3-DE1-PCRa'], dtype=object),
#  160: array(['E4-DE1-PCRa'], dtype=object),
#  161: array(['CC4-DE1-PCRa'], dtype=object),
#  162: array(['P0-DE1-PCRa'], dtype=object),
#  163: array(['K0-DE1-PCRa'], dtype=object),
#  164: array(['CC1-DE1-PCRa'], dtype=object),
#  165: array(['D2-DE1-PCRa'], dtype=object),
#  166: array(['BB2-DE1-PCRa'], dtype=object),
#  167: array(['K3-DE1-PCRa'], dtype=object),
#  168: array(['F4-DE1-PCRa'], dtype=object),
#  169: array(['DD4-DE1-PCRa'], dtype=object),
#  170: array(['AA0-DE1-PCRa'], dtype=object),
#  171: array(['F1-DE1-PCRa'], dtype=object),
#  172: array(['G0-DE1-PCRb'], dtype=object),
#  173: array(['E2-DE1-PCRa'], dtype=object),
#  174: array(['CC2-DE1-PCRa'], dtype=object),
#  175: array(['L3-DE1-PCRa'], dtype=object),
#  176: array(['G4-DE1-PCRa'], dtype=object),
#  177: array(['GG4-DE1-PCRa'], dtype=object),
#  178: array(['BB0-DE1-PCRa'], dtype=object),
#  179: array(['G1-DE1-PCRa'], dtype=object),
#  180: array(['H0-DE1-PCRb'], dtype=object),
#  181: array(['F2-DE1-PCRa'], dtype=object),
#  182: array(['DD2-DE1-PCRa'], dtype=object),
#  183: array(['O3-DE1-PCRa'], dtype=object),
#  184: array(['H4-DE1-PCRa'], dtype=object),
#  185: array(['B3-DE1-PCRa'], dtype=object),
#  186: array(['CC0-DE1-PCRa'], dtype=object),
#  187: array(['H1-DE1-PCRa'], dtype=object),
#  188: array(['J0-DE1-PCRb'], dtype=object),
#  189: array(['G2-DE1-PCRa'], dtype=object),
#  190: array(['GG2-DE1-PCRa'], dtype=object),
#  191: array(['P3-DE1-PCRa'], dtype=object),
#  192: array(['I4-DE1-PCRa'], dtype=object),
#  193: array(['C1-DE1-PCRa'], dtype=object),
#  194: array(['DD0-DE1-PCRa'], dtype=object),
#  195: array(['I1-DE1-PCRa'], dtype=object),
#  196: array(['K0-DE1-PCRb'], dtype=object),
#  197: array(['H2-DE1-PCRa'], dtype=object),
#  198: array(['A3-DE1-PCRa'], dtype=object),
#  199: array(['AA3-DE1-PCRa'], dtype=object),
#  200: array(['J4-DE1-PCRa'], dtype=object),
#  201: array(['Y1-DE1-PCRa'], dtype=object),
#  202: array(['EE0-DE1-PCRa'], dtype=object),
#  203: array(['EE1-DE1-PCRa'], dtype=object),
#  204: array(['EE2-DE1-PCRa'], dtype=object),
#  205: array(['EE3-DE1-PCRa'], dtype=object),
#  206: array(['EE4-DE1-PCRa'], dtype=object),
#  207: array(['FF0-DE1-PCRa'], dtype=object),
#  208: array(['FF1-DE1-PCRa'], dtype=object),
#  209: array(['FF2-DE1-PCRa'], dtype=object),
#  210: array(['FF3-DE1-PCRa'], dtype=object),
#  211: array(['FF4-DE1-PCRa'], dtype=object),
#  212: array(['M0-DE1-PCRa'], dtype=object),
#  213: array(['M1-DE1-PCRa'], dtype=object),
#  214: array(['M2-DE1-PCRa'], dtype=object),
#  215: array(['M3-DE1-PCRa'], dtype=object),
#  216: array(['M4-DE1-PCRa'], dtype=object),
#  217: array(['N0-DE1-PCRa'], dtype=object),
#  218: array(['N1-DE1-PCRa'], dtype=object),
#  219: array(['N2-DE1-PCRa'], dtype=object),
#  220: array(['N3-DE1-PCRa'], dtype=object),
#  221: array(['N4-DE1-PCRa'], dtype=object),
#  222: array(['Q0-DE1-PCRa'], dtype=object),
#  223: array(['Q1-DE1-PCRa'], dtype=object),
#  224: array(['Q2-DE1-PCRa'], dtype=object),
#  225: array(['Q3-DE1-PCRa'], dtype=object),
#  226: array(['Q4-DE1-PCRa'], dtype=object),
#  227: array(['R0-DE1-PCRa'], dtype=object),
#  228: array(['R1-DE1-PCRa'], dtype=object),
#  229: array(['R2-DE1-PCRa'], dtype=object),
#  230: array(['R3-DE1-PCRa'], dtype=object),
#  231: array(['R4-DE1-PCRa'], dtype=object),
#  232: array(['S0-DE1-PCRa', 'X1-DE1-PCRa'], dtype=object),
#  233: array(['S1-DE1-PCRa'], dtype=object),
#  234: array(['S2-DE1-PCRa'], dtype=object),
#  235: array(['S3-DE1-PCRa'], dtype=object),
#  236: array(['S4-DE1-PCRa'], dtype=object),
#  237: array(['T0-DE1-PCRa'], dtype=object),
#  238: array(['T1-DE1-PCRa'], dtype=object),
#  239: array(['T2-DE1-PCRa'], dtype=object),
#  240: array(['T3-DE1-PCRa'], dtype=object),
#  241: array(['T4-DE1-PCRa'], dtype=object),
#  242: array(['U0-DE1-PCRa'], dtype=object),
#  243: array(['U1-DE1-PCRa'], dtype=object),
#  244: array(['U2-DE1-PCRa'], dtype=object),
#  245: array(['U3-DE1-PCRa'], dtype=object),
#  246: array(['U4-DE1-PCRa'], dtype=object),
#  247: array(['V0-DE1-PCRa'], dtype=object),
#  248: array(['V1-DE1-PCRa'], dtype=object),
#  249: array(['V2-DE1-PCRa'], dtype=object),
#  250: array(['V3-DE1-PCRa'], dtype=object),
#  251: array(['V4-DE1-PCRa'], dtype=object),
#  252: array(['W0-DE1-PCRa'], dtype=object),
#  253: array(['W1-DE1-PCRa'], dtype=object),
#  254: array(['W2-DE1-PCRa'], dtype=object),
#  255: array(['W3-DE1-PCRa'], dtype=object),
#  256: array(['W4-DE1-PCRa'], dtype=object),
#  257: array(['X0-DE1-PCRa'], dtype=object),
#  258: array(['X2-DE1-PCRa'], dtype=object),
#  259: array(['X3-DE1-PCRa'], dtype=object),
#  260: array(['X4-DE1-PCRa'], dtype=object),
#  261: array(['1.4%-T0'], dtype=object),
#  262: array(['1.5%-T0'], dtype=object),
#  263: array(['1.6%-T0'], dtype=object),
#  264: array(['1.7%-T0'], dtype=object),
#  265: array(['1.8%-T0'], dtype=object),
#  266: array(['2.5%-T0'], dtype=object),
#  267: array(['Ben0.4-T0'], dtype=object),
#  268: array(['Ben2-T0'], dtype=object),
#  269: array(['1.4%-R1-T1'], dtype=object),
#  270: array(['1.5%-R1-T1'], dtype=object),
#  271: array(['1.6%-R1-T1'], dtype=object),
#  272: array(['1.7%-R1-T1'], dtype=object),
#  273: array(['1.8%-R1-T1'], dtype=object),
#  274: array(['2.5%-R1-T1'], dtype=object),
#  275: array(['Ben0.4-R1-T1'], dtype=object),
#  276: array(['Ben2-R1-T1'], dtype=object),
#  277: array(['1.4%-R1-T2'], dtype=object),
#  278: array(['1.5%-R1-T2'], dtype=object),
#  279: array(['1.6%-R1-T2'], dtype=object),
#  280: array(['1.7%-R1-T2'], dtype=object),
#  281: array(['1.8%-R1-T2'], dtype=object),
#  282: array(['2.5%-R1-T2'], dtype=object),
#  283: array(['Ben0.4-R1-T2'], dtype=object),
#  284: array(['Ben2-R1-T2'], dtype=object),
#  285: array(['1.4%-R1-T3'], dtype=object),
#  286: array(['1.5%-R1-T3'], dtype=object),
#  287: array(['1.6%-R1-T3'], dtype=object),
#  288: array(['1.7%-R1-T3'], dtype=object),
#  289: array(['1.8%-R1-T3'], dtype=object),
#  290: array(['2.5%-R1-T3'], dtype=object),
#  291: array(['Ben0.4-R1-T3'], dtype=object),
#  292: array(['Ben2-R1-T3'], dtype=object),
#  293: array(['1.4%-R1-T4'], dtype=object),
#  294: array(['1.5%-R1-T4'], dtype=object),
#  295: array(['1.6%-R1-T4'], dtype=object),
#  296: array(['1.7%-R1-T4'], dtype=object),
#  297: array(['1.8%-R1-T4'], dtype=object),
#  298: array(['2.5%-R1-T4'], dtype=object),
#  299: array(['Ben0.4-R1-T4'], dtype=object),
#  300: array(['Ben2-R1-T4'], dtype=object),
#  301: array(['1.4%-R2-T1'], dtype=object),
#  302: array(['1.5%-R2-T1'], dtype=object),
#  303: array(['1.6%-R2-T1'], dtype=object),
#  304: array(['1.7%-R2-T1'], dtype=object),
#  305: array(['1.8%-R2-T1'], dtype=object),
#  306: array(['2.5%-R2-T1'], dtype=object),
#  307: array(['Ben0.4-R2-T1'], dtype=object),
#  308: array(['Ben2-R2-T1'], dtype=object),
#  309: array(['1.4%-R2-T2'], dtype=object),
#  310: array(['1.5%-R2-T2'], dtype=object),
#  311: array(['1.6%-R2-T2'], dtype=object),
#  312: array(['1.7%-R2-T2'], dtype=object),
#  313: array(['1.8%-R2-T2'], dtype=object),
#  314: array(['2.5%-R2-T2'], dtype=object),
#  315: array(['Ben0.4-R2-T2'], dtype=object),
#  316: array(['Ben2-R2-T2'], dtype=object),
#  317: array(['1.4%-R2-T3'], dtype=object),
#  318: array(['1.5%-R2-T3'], dtype=object),
#  319: array(['1.6%-R2-T3'], dtype=object),
#  320: array(['1.7%-R2-T3'], dtype=object),
#  321: array(['1.8%-R2-T3'], dtype=object),
#  322: array(['2.5%-R2-T3'], dtype=object),
#  323: array(['Ben0.4-R2-T3'], dtype=object),
#  324: array(['Ben2-R2-T3'], dtype=object),
#  325: array(['1.4%-R2-T4'], dtype=object),
#  326: array(['1.5%-R2-T4'], dtype=object),
#  327: array(['1.6%-R2-T4'], dtype=object),
#  328: array(['1.7%-R2-T4'], dtype=object),
#  329: array(['1.8%-R2-T4'], dtype=object),
#  330: array(['2.5%-R2-T4'], dtype=object),
#  331: array(['Ben0.4-R2-T4'], dtype=object),
#  332: array(['Ben2-R2-T4'], dtype=object),
#  333: array(['Ben10-T0'], dtype=object),
#  334: array(['Ben10-R1-T1'], dtype=object),
#  335: array(['Ben10-R1-T2'], dtype=object),
#  336: array(['Ben10-R1-T3'], dtype=object),
#  337: array(['Ben10-R1-T4'], dtype=object),
#  338: array(['Ben10-R2-T1'], dtype=object),
#  339: array(['Ben10-R2-T2'], dtype=object),
#  340: array(['Ben10-R2-T3'], dtype=object),
#  341: array(['Ben10-R2-T4'], dtype=object),
#  342: array(['EE0-DE1-PCRa'], dtype=object),
#  343: array(['EE1-DE1-PCRa'], dtype=object),
#  344: array(['EE2-DE1-PCRa'], dtype=object),
#  345: array(['EE3-DE1-PCRa'], dtype=object),
#  346: array(['EE4-DE1-PCRa'], dtype=object),
#  347: array(['FF0-DE1-PCRa'], dtype=object),
#  348: array(['FF1-DE1-PCRa'], dtype=object),
#  349: array(['FF2-DE1-PCRa'], dtype=object),
#  350: array(['FF3-DE1-PCRa'], dtype=object),
#  351: array(['FF4-DE1-PCRa'], dtype=object),
#  352: array(['M0-DE1-PCRa'], dtype=object),
#  353: array(['M1-DE1-PCRa'], dtype=object),
#  354: array(['M2-DE1-PCRa'], dtype=object),
#  355: array(['M3-DE1-PCRa'], dtype=object),
#  356: array(['M4-DE1-PCRa'], dtype=object),
#  357: array(['N0-DE1-PCRa'], dtype=object),
#  358: array(['N1-DE1-PCRa'], dtype=object),
#  359: array(['N2-DE1-PCRa'], dtype=object),
#  360: array(['N3-DE1-PCRa'], dtype=object),
#  361: array(['N4-DE1-PCRa'], dtype=object),
#  362: array(['Q0-DE1-PCRa'], dtype=object),
#  363: array(['Q1-DE1-PCRa'], dtype=object),
#  364: array(['Q2-DE1-PCRa'], dtype=object),
#  365: array(['Q3-DE1-PCRa'], dtype=object),
#  366: array(['Q4-DE1-PCRa'], dtype=object),
#  367: array(['R0-DE1-PCRa'], dtype=object),
#  368: array(['R1-DE1-PCRa'], dtype=object),
#  369: array(['R2-DE1-PCRa'], dtype=object),
#  370: array(['R3-DE1-PCRa'], dtype=object),
#  371: array(['R4-DE1-PCRa'], dtype=object),
#  372: array(['S0-DE1-PCRa', 'X1-DE1-PCRa'], dtype=object),
#  373: array(['S1-DE1-PCRa'], dtype=object),
#  374: array(['S2-DE1-PCRa'], dtype=object),
#  375: array(['S3-DE1-PCRa'], dtype=object),
#  376: array(['S4-DE1-PCRa'], dtype=object),
#  377: array(['T0-DE1-PCRa'], dtype=object),
#  378: array(['T1-DE1-PCRa'], dtype=object),
#  379: array(['T2-DE1-PCRa'], dtype=object),
#  380: array(['T3-DE1-PCRa'], dtype=object),
#  381: array(['T4-DE1-PCRa'], dtype=object),
#  382: array(['U0-DE1-PCRa'], dtype=object),
#  383: array(['U1-DE1-PCRa'], dtype=object),
#  384: array(['U2-DE1-PCRa'], dtype=object),
#  385: array(['U3-DE1-PCRa'], dtype=object),
#  386: array(['U4-DE1-PCRa'], dtype=object),
#  387: array(['V0-DE1-PCRa'], dtype=object),
#  388: array(['V1-DE1-PCRa'], dtype=object),
#  389: array(['V2-DE1-PCRa'], dtype=object),
#  390: array(['V3-DE1-PCRa'], dtype=object),
#  391: array(['V4-DE1-PCRa'], dtype=object),
#  392: array(['W0-DE1-PCRa'], dtype=object),
#  393: array(['W1-DE1-PCRa'], dtype=object),
#  394: array(['W2-DE1-PCRa'], dtype=object),
#  395: array(['W3-DE1-PCRa'], dtype=object),
#  396: array(['W4-DE1-PCRa'], dtype=object),
#  397: array(['X0-DE1-PCRa'], dtype=object),
#  398: array(['X2-DE1-PCRa'], dtype=object),
#  399: array(['X3-DE1-PCRa'], dtype=object),
#  400: array(['X4-DE1-PCRa'], dtype=object),
#  401: array(['EE0-DE1-PCRa'], dtype=object),
#  402: array(['EE1-DE1-PCRa'], dtype=object),
#  403: array(['EE2-DE1-PCRa'], dtype=object),
#  404: array(['EE3-DE1-PCRa'], dtype=object),
#  405: array(['EE4-DE1-PCRa'], dtype=object),
#  406: array(['FF0-DE1-PCRa'], dtype=object),
#  407: array(['FF1-DE1-PCRa'], dtype=object),
#  408: array(['FF2-DE1-PCRa'], dtype=object),
#  409: array(['FF3-DE1-PCRa'], dtype=object),
#  410: array(['FF4-DE1-PCRa'], dtype=object),
#  411: array(['M0-DE1-PCRa'], dtype=object),
#  412: array(['M1-DE1-PCRa'], dtype=object),
#  413: array(['M2-DE1-PCRa'], dtype=object),
#  414: array(['M3-DE1-PCRa'], dtype=object),
#  415: array(['M4-DE1-PCRa'], dtype=object),
#  416: array(['N0-DE1-PCRa'], dtype=object),
#  417: array(['N1-DE1-PCRa'], dtype=object),
#  418: array(['N2-DE1-PCRa'], dtype=object),
#  419: array(['N3-DE1-PCRa'], dtype=object),
#  420: array(['N4-DE1-PCRa'], dtype=object),
#  421: array(['Q0-DE1-PCRa'], dtype=object),
#  422: array(['Q1-DE1-PCRa'], dtype=object),
#  423: array(['Q2-DE1-PCRa'], dtype=object),
#  424: array(['Q3-DE1-PCRa'], dtype=object),
#  425: array(['Q4-DE1-PCRa'], dtype=object),
#  426: array(['R0-DE1-PCRa'], dtype=object),
#  427: array(['R1-DE1-PCRa'], dtype=object),
#  428: array(['R2-DE1-PCRa'], dtype=object),
#  429: array(['R3-DE1-PCRa'], dtype=object),
#  430: array(['R4-DE1-PCRa'], dtype=object),
#  431: array(['S0-DE1-PCRa', 'X1-DE1-PCRa'], dtype=object),
#  432: array(['S1-DE1-PCRa'], dtype=object),
#  433: array(['S2-DE1-PCRa'], dtype=object),
#  434: array(['S3-DE1-PCRa'], dtype=object),
#  435: array(['S4-DE1-PCRa'], dtype=object),
#  436: array(['T0-DE1-PCRa'], dtype=object),
#  437: array(['T1-DE1-PCRa'], dtype=object),
#  438: array(['T2-DE1-PCRa'], dtype=object),
#  439: array(['T3-DE1-PCRa'], dtype=object),
#  440: array(['T4-DE1-PCRa'], dtype=object),
#  441: array(['U0-DE1-PCRa'], dtype=object),
#  442: array(['U1-DE1-PCRa'], dtype=object),
#  443: array(['U2-DE1-PCRa'], dtype=object),
#  444: array(['U3-DE1-PCRa'], dtype=object),
#  445: array(['U4-DE1-PCRa'], dtype=object),
#  446: array(['V0-DE1-PCRa'], dtype=object),
#  447: array(['V1-DE1-PCRa'], dtype=object),
#  448: array(['V2-DE1-PCRa'], dtype=object),
#  449: array(['V3-DE1-PCRa'], dtype=object),
#  450: array(['V4-DE1-PCRa'], dtype=object),
#  451: array(['W0-DE1-PCRa'], dtype=object),
#  452: array(['W1-DE1-PCRa'], dtype=object),
#  453: array(['W2-DE1-PCRa'], dtype=object),
#  454: array(['W3-DE1-PCRa'], dtype=object),
#  455: array(['W4-DE1-PCRa'], dtype=object),
#  456: array(['X0-DE1-PCRa'], dtype=object),
#  457: array(['X2-DE1-PCRa'], dtype=object),
#  458: array(['X3-DE1-PCRa'], dtype=object),
#  459: array(['X4-DE1-PCRa'], dtype=object),
#  460: array(['EE0-DE1-PCRa'], dtype=object),
#  461: array(['EE1-DE1-PCRa'], dtype=object),
#  462: array(['EE2-DE1-PCRa'], dtype=object),
#  463: array(['EE3-DE1-PCRa'], dtype=object),
#  464: array(['EE4-DE1-PCRa'], dtype=object),
#  465: array(['FF0-DE1-PCRa'], dtype=object),
#  466: array(['FF1-DE1-PCRa'], dtype=object),
#  467: array(['FF2-DE1-PCRa'], dtype=object),
#  468: array(['FF3-DE1-PCRa'], dtype=object),
#  469: array(['FF4-DE1-PCRa'], dtype=object),
#  470: array(['M0-DE1-PCRa'], dtype=object),
#  471: array(['M1-DE1-PCRa'], dtype=object),
#  472: array(['M2-DE1-PCRa'], dtype=object),
#  473: array(['M3-DE1-PCRa'], dtype=object),
#  474: array(['M4-DE1-PCRa'], dtype=object),
#  475: array(['N0-DE1-PCRa'], dtype=object),
#  476: array(['N1-DE1-PCRa'], dtype=object),
#  477: array(['N2-DE1-PCRa'], dtype=object),
#  478: array(['N3-DE1-PCRa'], dtype=object),
#  479: array(['N4-DE1-PCRa'], dtype=object),
#  480: array(['Q0-DE1-PCRa'], dtype=object),
#  481: array(['Q1-DE1-PCRa'], dtype=object),
#  482: array(['Q2-DE1-PCRa'], dtype=object),
#  483: array(['Q3-DE1-PCRa'], dtype=object),
#  484: array(['Q4-DE1-PCRa'], dtype=object),
#  485: array(['R0-DE1-PCRa'], dtype=object),
#  486: array(['R1-DE1-PCRa'], dtype=object),
#  487: array(['R2-DE1-PCRa'], dtype=object),
#  488: array(['R3-DE1-PCRa'], dtype=object),
#  489: array(['R4-DE1-PCRa'], dtype=object),
#  490: array(['S0-DE1-PCRa', 'X1-DE1-PCRa'], dtype=object),
#  491: array(['S1-DE1-PCRa'], dtype=object),
#  492: array(['S2-DE1-PCRa'], dtype=object),
#  493: array(['S3-DE1-PCRa'], dtype=object),
#  494: array(['S4-DE1-PCRa'], dtype=object),
#  495: array(['T0-DE1-PCRa'], dtype=object),
#  496: array(['T1-DE1-PCRa'], dtype=object),
#  497: array(['T2-DE1-PCRa'], dtype=object),
#  498: array(['T3-DE1-PCRa'], dtype=object),
#  499: array(['T4-DE1-PCRa'], dtype=object),
#  500: array(['U0-DE1-PCRa'], dtype=object),
#  501: array(['U1-DE1-PCRa'], dtype=object),
#  502: array(['U2-DE1-PCRa'], dtype=object),
#  503: array(['U3-DE1-PCRa'], dtype=object),
#  504: array(['U4-DE1-PCRa'], dtype=object),
#  505: array(['V0-DE1-PCRa'], dtype=object),
#  506: array(['V1-DE1-PCRa'], dtype=object),
#  507: array(['V2-DE1-PCRa'], dtype=object),
#  508: array(['V3-DE1-PCRa'], dtype=object),
#  509: array(['V4-DE1-PCRa'], dtype=object),
#  510: array(['W0-DE1-PCRa'], dtype=object),
#  511: array(['W1-DE1-PCRa'], dtype=object),
#  512: array(['W2-DE1-PCRa'], dtype=object),
#  513: array(['W3-DE1-PCRa'], dtype=object),
#  514: array(['W4-DE1-PCRa'], dtype=object),
#  515: array(['X0-DE1-PCRa'], dtype=object),
#  516: array(['X2-DE1-PCRa'], dtype=object),
#  517: array(['X3-DE1-PCRa'], dtype=object),
#  518: array(['X4-DE1-PCRa'], dtype=object),
#  519: array(['A0-DE2-PCRa'], dtype=object),
#  520: array(['A4-DE1-PCRb'], dtype=object),
#  521: array(['D1-DE1-PCRb'], dtype=object),
#  522: array(['E0-DE2-PCRa'], dtype=object),
#  523: array(['E4-DE1-PCRb'], dtype=object),
#  524: array(['F3-DE1-PCRb'], dtype=object),
#  525: array(['B2-DE1-PCRc'], dtype=object),
#  526: array(['C0-DE1-PCRc'], dtype=object),
#  527: array(['A1-DE1-PCRb'], dtype=object),
#  528: array(['Tneg-DE3-PCRa'], dtype=object),
#  529: array(['D2-DE1-PCRb'], dtype=object),
#  530: array(['E1-DE2-PCRa'], dtype=object),
#  531: array(['F0-DE2-PCRa'], dtype=object),
#  532: array(['F4-DE1-PCRb'], dtype=object),
#  533: array(['B3-DE1-PCRc'], dtype=object),
#  534: array(['C2-DE3-PCRb'], dtype=object),
#  535: array(['A2-DE1-PCRb'], dtype=object),
#  536: array(['B1-DE2-PCRa'], dtype=object),
#  537: array(['D3-DE1-PCRb'], dtype=object),
#  538: array(['E2-DE1-PCRb'], dtype=object),
#  539: array(['F1-DE1-PCRb'], dtype=object),
#  540: array(['C2-DE3-PCRa'], dtype=object),
#  541: array(['B4-DE5-PCRa'], dtype=object),
#  542: array(['C3-DE2-PCRa'], dtype=object),
#  543: array(['A3-DE1-PCRb'], dtype=object),
#  544: array(['D0-DE2-PCRa'], dtype=object),
#  545: array(['D4-DE1-PCRb'], dtype=object),
#  546: array(['E3-DE1-PCRb'], dtype=object),
#  547: array(['F2-DE1-PCRb'], dtype=object),
#  548: array(['C4-DE3-PCRa'], dtype=object),
#  549: array(['C1-DE1-PCRc'], dtype=object),
#  550: array(['C4-DE3-PCRb'], dtype=object),
#  551: array(['13-0', '13-0_pool', '13-1-1', '13-1-2', '13-1-3', '13-2-1',
#         '13-2-2', '13-2-3', '13-3-1', '13-3-2', '13-3-3', '13-4-1',
#         '13-4-2', '13-4-3'], dtype=object),
#  552: array(['18-1-1', '18-1-2', '18-1-3', '18-2-1', '18-2-2', '18-2-3',
#         '18-3-1', '18-3-2', '18-3-3', '18-4-1', '18-4-2', '18-4-3'],
#        dtype=object),
#  553: array(['3-0', '3-1-1', '3-1-2', '3-1-3', '3-2-1', '3-2-2', '3-2-3',
#         '3-3-1', '3-3-2', '3-3-3', '3-4-1', '3-4-2', '3-4-3'], dtype=object),
#  554: array(['20-1-1', '20-1-2', '20-1-3', '20-2-1', '20-2-2', '20-2-3',
#         '20-3-1', '20-3-2', '20-3-3', '20-4-1', '20-4-2', '20-4-3',
#         '21-0-1', '21-0-2', '21-0-4', '21-1-1', '21-1-2', '21-1-3',
#         '21-2-1', '21-2-2', '21-2-3', '21-3-1', '21-3-2', '21-3-3',
#         '21-4-1', '21-4-2', '21-4-3', '21+wt', '23-0', '23-1-1', '23-1-2',
#         '23-1-3', '23-2-1', '23-2-2', '23-2-3', '23-3-1', '23-3-2',
#         '23-3-3', '23-4-1', '23-4-2', '23-4-3'], dtype=object),
#  555: array(['6-0', '6-1-1', '6-1-2', '6-1-3', '6-2-1', '6-2-2', '6-2-3',
#         '6-3-1', '6-3-2', '6-3-3', '6-4-1', '6-4-2', '6-4-3'], dtype=object)}

# %%
groups = {}

# First assign each entry to a group
for g,lane in enumerate(np.unique(samples['lane'].values)):
    groups[g] = samples[samples['lane']==lane]['sample'].values

# merge groups when samples are the same
groups_merged = {}
group_counter = 0
for g1,group1 in groups.items():
    
    if g1 not in groups_merged:
        groups_merged[g1] = group_counter
        group_counter +=1 
    
    for g2,group2 in groups.items():
        if g1 < g2: # for every pair of groups
            intersection = set(group1).intersection(set(group2))
            if len(intersection) > 0:
                
                if g1 in groups_merged.keys():
                    groups_merged[g2] = groups_merged[g1]
                else:
                    
                    groups_merged[g1] = group_counter
                    groups_merged[g2] = group_counter
                    group_counter += 1

                    ## invert the merged groups                
group_merger = {}
for k, v in groups_merged.items():
    group_merger.setdefault(v, set()).add(k)

actual_groups = {}
for g,group_names in group_merger.items():
    actual_groups[g] = np.unique(flatten([groups[name] for name in group_names]))

# %%
actual_groups
# Out:
# {0: array(['B0-DE1-PCRa', 'B0-DE2-PCRa', 'B0-DE2-PCRb', 'B0-DE2-PCRc',
#         'B0-DE3-PCRa', 'B0-DE4-PCRa', 'B1-DE1-PCRa', 'B2-DE1-PCRa',
#         'B2-DE1-PCRb', 'B2-DE2-PCRa', 'B2-DE3-PCRa', 'B2-DE4-PCRa',
#         'B3-DE1-PCRa', 'B3-DE1-PCRb', 'B4-DE1-PCRa', 'B4-DE2-PCRa',
#         'B4-DE2-PCRb', 'B4-DE3-PCRa', 'B4-DE4-PCRa', 'C0-DE1-PCRa',
#         'C0-DE1-PCRb', 'C0-DE2-PCRa', 'C1-DE1-PCRa', 'C1-DE1-PCRb',
#         'C2-DE1-PCRa', 'C2-DE2-PCRa', 'C3-DE1-PCRa', 'C4-DE1-PCRa',
#         'C4-DE2-PCRa', 'Tneg-DE1-PCRa', 'Tneg-DE2-PCRa', 'Y0-DE1-PCRa',
#         'Y0-DE2-PCRa', 'Y0-DE2-PCRb', 'Y0-DE3-PCRa', 'Y0-DE4-PCRa',
#         'Y1-DE1-PCRa', 'Y1-DE1-PCRb', 'Y2-DE1-PCRa', 'Y2-DE1-PCRb',
#         'Y2-DE2-PCRa', 'Y2-DE3-PCRa', 'Y2-DE4-PCRa', 'Y3-DE1-PCRa',
#         'Y4-DE1-PCRa', 'Y4-DE1-PCRb', 'Y4-DE2-PCRa', 'Y4-DE3-PCRa',
#         'Y4-DE4-PCRa', 'Z0-DE1-PCRa', 'Z0-DE2-PCRa', 'Z1-DE1-PCRa',
#         'Z2-DE1-PCRa', 'Z2-DE1-PCRb', 'Z2-DE2-PCRa', 'Z3-DE1-PCRa',
#         'Z4-DE1-PCRa', 'Z4-DE2-PCRa'], dtype='<U13'),
#  1: array(['E0-DE1-PCRb'], dtype='<U11'),
#  2: array(['E1-DE1-PCRa'], dtype='<U11'),
#  3: array(['P1-DE1-PCRa'], dtype='<U11'),
#  4: array(['GG1-DE1-PCRa'], dtype='<U12'),
#  5: array(['AA2-DE1-PCRa'], dtype='<U12'),
#  6: array(['K3-DE1-PCRa'], dtype='<U11'),
#  7: array(['G4-DE1-PCRa'], dtype='<U11'),
#  8: array(['A0-DE1-PCRb'], dtype='<U11'),
#  9: array(['GG0-DE1-PCRa'], dtype='<U12'),
#  10: array(['J1-DE1-PCRa'], dtype='<U11'),
#  11: array(['A0-DE1-PCRa'], dtype='<U11'),
#  12: array(['I2-DE1-PCRa'], dtype='<U11'),
#  13: array(['D3-DE1-PCRa'], dtype='<U11'),
#  14: array(['BB3-DE1-PCRa'], dtype='<U12'),
#  15: array(['K4-DE1-PCRa'], dtype='<U11'),
#  16: array(['D0-DE1-PCRb'], dtype='<U11'),
#  17: array(['A1-DE1-PCRa'], dtype='<U11'),
#  18: array(['K1-DE1-PCRa'], dtype='<U11'),
#  19: array(['D0-DE1-PCRa'], dtype='<U11'),
#  20: array(['J2-DE1-PCRa'], dtype='<U11'),
#  21: array(['E3-DE1-PCRa'], dtype='<U11'),
#  22: array(['CC3-DE1-PCRa'], dtype='<U12'),
#  23: array(['L4-DE1-PCRa'], dtype='<U11'),
#  24: array(['D1-DE1-PCRa'], dtype='<U11'),
#  25: array(['L1-DE1-PCRa'], dtype='<U11'),
#  26: array(['E0-DE1-PCRa'], dtype='<U11'),
#  27: array(['K2-DE1-PCRa'], dtype='<U11'),
#  28: array(['F3-DE1-PCRa'], dtype='<U11'),
#  29: array(['DD3-DE1-PCRa'], dtype='<U12'),
#  30: array(['O4-DE1-PCRa'], dtype='<U11'),
#  31: array(['F0-DE1-PCRb'], dtype='<U11'),
#  32: array(['O1-DE1-PCRa'], dtype='<U11'),
#  33: array(['F0-DE1-PCRa'], dtype='<U11'),
#  34: array(['L2-DE1-PCRa'], dtype='<U11'),
#  35: array(['G3-DE1-PCRa'], dtype='<U11'),
#  36: array(['GG3-DE1-PCRa'], dtype='<U12'),
#  37: array(['P4-DE1-PCRa'], dtype='<U11'),
#  38: array(['I0-DE1-PCRa'], dtype='<U11'),
#  39: array(['G0-DE1-PCRa'], dtype='<U11'),
#  40: array(['DD1-DE1-PCRa'], dtype='<U12'),
#  41: array(['O2-DE1-PCRa'], dtype='<U11'),
#  42: array(['H3-DE1-PCRa'], dtype='<U11'),
#  43: array(['A4-DE1-PCRa'], dtype='<U11'),
#  44: array(['AA4-DE1-PCRa'], dtype='<U12'),
#  45: array(['L0-DE1-PCRa'], dtype='<U11'),
#  46: array(['H0-DE1-PCRa'], dtype='<U11'),
#  47: array(['AA1-DE1-PCRa'], dtype='<U12'),
#  48: array(['P2-DE1-PCRa'], dtype='<U11'),
#  49: array(['I3-DE1-PCRa'], dtype='<U11'),
#  50: array(['D4-DE1-PCRa'], dtype='<U11'),
#  51: array(['BB4-DE1-PCRa'], dtype='<U12'),
#  52: array(['O0-DE1-PCRa'], dtype='<U11'),
#  53: array(['J0-DE1-PCRa'], dtype='<U11'),
#  54: array(['BB1-DE1-PCRa'], dtype='<U12'),
#  55: array(['A2-DE1-PCRa'], dtype='<U11'),
#  56: array(['J3-DE1-PCRa'], dtype='<U11'),
#  57: array(['E4-DE1-PCRa'], dtype='<U11'),
#  58: array(['CC4-DE1-PCRa'], dtype='<U12'),
#  59: array(['P0-DE1-PCRa'], dtype='<U11'),
#  60: array(['K0-DE1-PCRa'], dtype='<U11'),
#  61: array(['CC1-DE1-PCRa'], dtype='<U12'),
#  62: array(['D2-DE1-PCRa'], dtype='<U11'),
#  63: array(['BB2-DE1-PCRa'], dtype='<U12'),
#  64: array(['F4-DE1-PCRa'], dtype='<U11'),
#  65: array(['DD4-DE1-PCRa'], dtype='<U12'),
#  66: array(['AA0-DE1-PCRa'], dtype='<U12'),
#  67: array(['F1-DE1-PCRa'], dtype='<U11'),
#  68: array(['G0-DE1-PCRb'], dtype='<U11'),
#  69: array(['E2-DE1-PCRa'], dtype='<U11'),
#  70: array(['CC2-DE1-PCRa'], dtype='<U12'),
#  71: array(['L3-DE1-PCRa'], dtype='<U11'),
#  72: array(['GG4-DE1-PCRa'], dtype='<U12'),
#  73: array(['BB0-DE1-PCRa'], dtype='<U12'),
#  74: array(['G1-DE1-PCRa'], dtype='<U11'),
#  75: array(['H0-DE1-PCRb'], dtype='<U11'),
#  76: array(['F2-DE1-PCRa'], dtype='<U11'),
#  77: array(['DD2-DE1-PCRa'], dtype='<U12'),
#  78: array(['O3-DE1-PCRa'], dtype='<U11'),
#  79: array(['H4-DE1-PCRa'], dtype='<U11'),
#  80: array(['CC0-DE1-PCRa'], dtype='<U12'),
#  81: array(['H1-DE1-PCRa'], dtype='<U11'),
#  82: array(['J0-DE1-PCRb'], dtype='<U11'),
#  83: array(['G2-DE1-PCRa'], dtype='<U11'),
#  84: array(['GG2-DE1-PCRa'], dtype='<U12'),
#  85: array(['P3-DE1-PCRa'], dtype='<U11'),
#  86: array(['I4-DE1-PCRa'], dtype='<U11'),
#  87: array(['DD0-DE1-PCRa'], dtype='<U12'),
#  88: array(['I1-DE1-PCRa'], dtype='<U11'),
#  89: array(['K0-DE1-PCRb'], dtype='<U11'),
#  90: array(['H2-DE1-PCRa'], dtype='<U11'),
#  91: array(['A3-DE1-PCRa'], dtype='<U11'),
#  92: array(['AA3-DE1-PCRa'], dtype='<U12'),
#  93: array(['J4-DE1-PCRa'], dtype='<U11'),
#  94: array(['EE0-DE1-PCRa'], dtype='<U12'),
#  95: array(['EE1-DE1-PCRa'], dtype='<U12'),
#  96: array(['EE2-DE1-PCRa'], dtype='<U12'),
#  97: array(['EE3-DE1-PCRa'], dtype='<U12'),
#  98: array(['EE4-DE1-PCRa'], dtype='<U12'),
#  99: array(['FF0-DE1-PCRa'], dtype='<U12'),
#  100: array(['FF1-DE1-PCRa'], dtype='<U12'),
#  101: array(['FF2-DE1-PCRa'], dtype='<U12'),
#  102: array(['FF3-DE1-PCRa'], dtype='<U12'),
#  103: array(['FF4-DE1-PCRa'], dtype='<U12'),
#  104: array(['M0-DE1-PCRa'], dtype='<U11'),
#  105: array(['M1-DE1-PCRa'], dtype='<U11'),
#  106: array(['M2-DE1-PCRa'], dtype='<U11'),
#  107: array(['M3-DE1-PCRa'], dtype='<U11'),
#  108: array(['M4-DE1-PCRa'], dtype='<U11'),
#  109: array(['N0-DE1-PCRa'], dtype='<U11'),
#  110: array(['N1-DE1-PCRa'], dtype='<U11'),
#  111: array(['N2-DE1-PCRa'], dtype='<U11'),
#  112: array(['N3-DE1-PCRa'], dtype='<U11'),
#  113: array(['N4-DE1-PCRa'], dtype='<U11'),
#  114: array(['Q0-DE1-PCRa'], dtype='<U11'),
#  115: array(['Q1-DE1-PCRa'], dtype='<U11'),
#  116: array(['Q2-DE1-PCRa'], dtype='<U11'),
#  117: array(['Q3-DE1-PCRa'], dtype='<U11'),
#  118: array(['Q4-DE1-PCRa'], dtype='<U11'),
#  119: array(['R0-DE1-PCRa'], dtype='<U11'),
#  120: array(['R1-DE1-PCRa'], dtype='<U11'),
#  121: array(['R2-DE1-PCRa'], dtype='<U11'),
#  122: array(['R3-DE1-PCRa'], dtype='<U11'),
#  123: array(['R4-DE1-PCRa'], dtype='<U11'),
#  124: array(['S0-DE1-PCRa', 'X1-DE1-PCRa'], dtype='<U11'),
#  125: array(['S1-DE1-PCRa'], dtype='<U11'),
#  126: array(['S2-DE1-PCRa'], dtype='<U11'),
#  127: array(['S3-DE1-PCRa'], dtype='<U11'),
#  128: array(['S4-DE1-PCRa'], dtype='<U11'),
#  129: array(['T0-DE1-PCRa'], dtype='<U11'),
#  130: array(['T1-DE1-PCRa'], dtype='<U11'),
#  131: array(['T2-DE1-PCRa'], dtype='<U11'),
#  132: array(['T3-DE1-PCRa'], dtype='<U11'),
#  133: array(['T4-DE1-PCRa'], dtype='<U11'),
#  134: array(['U0-DE1-PCRa'], dtype='<U11'),
#  135: array(['U1-DE1-PCRa'], dtype='<U11'),
#  136: array(['U2-DE1-PCRa'], dtype='<U11'),
#  137: array(['U3-DE1-PCRa'], dtype='<U11'),
#  138: array(['U4-DE1-PCRa'], dtype='<U11'),
#  139: array(['V0-DE1-PCRa'], dtype='<U11'),
#  140: array(['V1-DE1-PCRa'], dtype='<U11'),
#  141: array(['V2-DE1-PCRa'], dtype='<U11'),
#  142: array(['V3-DE1-PCRa'], dtype='<U11'),
#  143: array(['V4-DE1-PCRa'], dtype='<U11'),
#  144: array(['W0-DE1-PCRa'], dtype='<U11'),
#  145: array(['W1-DE1-PCRa'], dtype='<U11'),
#  146: array(['W2-DE1-PCRa'], dtype='<U11'),
#  147: array(['W3-DE1-PCRa'], dtype='<U11'),
#  148: array(['W4-DE1-PCRa'], dtype='<U11'),
#  149: array(['X0-DE1-PCRa'], dtype='<U11'),
#  150: array(['X2-DE1-PCRa'], dtype='<U11'),
#  151: array(['X3-DE1-PCRa'], dtype='<U11'),
#  152: array(['X4-DE1-PCRa'], dtype='<U11'),
#  153: array(['1.4%-T0'], dtype='<U7'),
#  154: array(['1.5%-T0'], dtype='<U7'),
#  155: array(['1.6%-T0'], dtype='<U7'),
#  156: array(['1.7%-T0'], dtype='<U7'),
#  157: array(['1.8%-T0'], dtype='<U7'),
#  158: array(['2.5%-T0'], dtype='<U7'),
#  159: array(['Ben0.4-T0'], dtype='<U9'),
#  160: array(['Ben2-T0'], dtype='<U7'),
#  161: array(['1.4%-R1-T1'], dtype='<U10'),
#  162: array(['1.5%-R1-T1'], dtype='<U10'),
#  163: array(['1.6%-R1-T1'], dtype='<U10'),
#  164: array(['1.7%-R1-T1'], dtype='<U10'),
#  165: array(['1.8%-R1-T1'], dtype='<U10'),
#  166: array(['2.5%-R1-T1'], dtype='<U10'),
#  167: array(['Ben0.4-R1-T1'], dtype='<U12'),
#  168: array(['Ben2-R1-T1'], dtype='<U10'),
#  169: array(['1.4%-R1-T2'], dtype='<U10'),
#  170: array(['1.5%-R1-T2'], dtype='<U10'),
#  171: array(['1.6%-R1-T2'], dtype='<U10'),
#  172: array(['1.7%-R1-T2'], dtype='<U10'),
#  173: array(['1.8%-R1-T2'], dtype='<U10'),
#  174: array(['2.5%-R1-T2'], dtype='<U10'),
#  175: array(['Ben0.4-R1-T2'], dtype='<U12'),
#  176: array(['Ben2-R1-T2'], dtype='<U10'),
#  177: array(['1.4%-R1-T3'], dtype='<U10'),
#  178: array(['1.5%-R1-T3'], dtype='<U10'),
#  179: array(['1.6%-R1-T3'], dtype='<U10'),
#  180: array(['1.7%-R1-T3'], dtype='<U10'),
#  181: array(['1.8%-R1-T3'], dtype='<U10'),
#  182: array(['2.5%-R1-T3'], dtype='<U10'),
#  183: array(['Ben0.4-R1-T3'], dtype='<U12'),
#  184: array(['Ben2-R1-T3'], dtype='<U10'),
#  185: array(['1.4%-R1-T4'], dtype='<U10'),
#  186: array(['1.5%-R1-T4'], dtype='<U10'),
#  187: array(['1.6%-R1-T4'], dtype='<U10'),
#  188: array(['1.7%-R1-T4'], dtype='<U10'),
#  189: array(['1.8%-R1-T4'], dtype='<U10'),
#  190: array(['2.5%-R1-T4'], dtype='<U10'),
#  191: array(['Ben0.4-R1-T4'], dtype='<U12'),
#  192: array(['Ben2-R1-T4'], dtype='<U10'),
#  193: array(['1.4%-R2-T1'], dtype='<U10'),
#  194: array(['1.5%-R2-T1'], dtype='<U10'),
#  195: array(['1.6%-R2-T1'], dtype='<U10'),
#  196: array(['1.7%-R2-T1'], dtype='<U10'),
#  197: array(['1.8%-R2-T1'], dtype='<U10'),
#  198: array(['2.5%-R2-T1'], dtype='<U10'),
#  199: array(['Ben0.4-R2-T1'], dtype='<U12'),
#  200: array(['Ben2-R2-T1'], dtype='<U10'),
#  201: array(['1.4%-R2-T2'], dtype='<U10'),
#  202: array(['1.5%-R2-T2'], dtype='<U10'),
#  203: array(['1.6%-R2-T2'], dtype='<U10'),
#  204: array(['1.7%-R2-T2'], dtype='<U10'),
#  205: array(['1.8%-R2-T2'], dtype='<U10'),
#  206: array(['2.5%-R2-T2'], dtype='<U10'),
#  207: array(['Ben0.4-R2-T2'], dtype='<U12'),
#  208: array(['Ben2-R2-T2'], dtype='<U10'),
#  209: array(['1.4%-R2-T3'], dtype='<U10'),
#  210: array(['1.5%-R2-T3'], dtype='<U10'),
#  211: array(['1.6%-R2-T3'], dtype='<U10'),
#  212: array(['1.7%-R2-T3'], dtype='<U10'),
#  213: array(['1.8%-R2-T3'], dtype='<U10'),
#  214: array(['2.5%-R2-T3'], dtype='<U10'),
#  215: array(['Ben0.4-R2-T3'], dtype='<U12'),
#  216: array(['Ben2-R2-T3'], dtype='<U10'),
#  217: array(['1.4%-R2-T4'], dtype='<U10'),
#  218: array(['1.5%-R2-T4'], dtype='<U10'),
#  219: array(['1.6%-R2-T4'], dtype='<U10'),
#  220: array(['1.7%-R2-T4'], dtype='<U10'),
#  221: array(['1.8%-R2-T4'], dtype='<U10'),
#  222: array(['2.5%-R2-T4'], dtype='<U10'),
#  223: array(['Ben0.4-R2-T4'], dtype='<U12'),
#  224: array(['Ben2-R2-T4'], dtype='<U10'),
#  225: array(['Ben10-T0'], dtype='<U8'),
#  226: array(['Ben10-R1-T1'], dtype='<U11'),
#  227: array(['Ben10-R1-T2'], dtype='<U11'),
#  228: array(['Ben10-R1-T3'], dtype='<U11'),
#  229: array(['Ben10-R1-T4'], dtype='<U11'),
#  230: array(['Ben10-R2-T1'], dtype='<U11'),
#  231: array(['Ben10-R2-T2'], dtype='<U11'),
#  232: array(['Ben10-R2-T3'], dtype='<U11'),
#  233: array(['Ben10-R2-T4'], dtype='<U11'),
#  234: array(['A0-DE2-PCRa'], dtype='<U11'),
#  235: array(['A4-DE1-PCRb'], dtype='<U11'),
#  236: array(['D1-DE1-PCRb'], dtype='<U11'),
#  237: array(['E0-DE2-PCRa'], dtype='<U11'),
#  238: array(['E4-DE1-PCRb'], dtype='<U11'),
#  239: array(['F3-DE1-PCRb'], dtype='<U11'),
#  240: array(['B2-DE1-PCRc'], dtype='<U11'),
#  241: array(['C0-DE1-PCRc'], dtype='<U11'),
#  242: array(['A1-DE1-PCRb'], dtype='<U11'),
#  243: array(['Tneg-DE3-PCRa'], dtype='<U13'),
#  244: array(['D2-DE1-PCRb'], dtype='<U11'),
#  245: array(['E1-DE2-PCRa'], dtype='<U11'),
#  246: array(['F0-DE2-PCRa'], dtype='<U11'),
#  247: array(['F4-DE1-PCRb'], dtype='<U11'),
#  248: array(['B3-DE1-PCRc'], dtype='<U11'),
#  249: array(['C2-DE3-PCRb'], dtype='<U11'),
#  250: array(['A2-DE1-PCRb'], dtype='<U11'),
#  251: array(['B1-DE2-PCRa'], dtype='<U11'),
#  252: array(['D3-DE1-PCRb'], dtype='<U11'),
#  253: array(['E2-DE1-PCRb'], dtype='<U11'),
#  254: array(['F1-DE1-PCRb'], dtype='<U11'),
#  255: array(['C2-DE3-PCRa'], dtype='<U11'),
#  256: array(['B4-DE5-PCRa'], dtype='<U11'),
#  257: array(['C3-DE2-PCRa'], dtype='<U11'),
#  258: array(['A3-DE1-PCRb'], dtype='<U11'),
#  259: array(['D0-DE2-PCRa'], dtype='<U11'),
#  260: array(['D4-DE1-PCRb'], dtype='<U11'),
#  261: array(['E3-DE1-PCRb'], dtype='<U11'),
#  262: array(['F2-DE1-PCRb'], dtype='<U11'),
#  263: array(['C4-DE3-PCRa'], dtype='<U11'),
#  264: array(['C1-DE1-PCRc'], dtype='<U11'),
#  265: array(['C4-DE3-PCRb'], dtype='<U11'),
#  266: array(['13-0', '13-0_pool', '13-1-1', '13-1-2', '13-1-3', '13-2-1',
#         '13-2-2', '13-2-3', '13-3-1', '13-3-2', '13-3-3', '13-4-1',
#         '13-4-2', '13-4-3'], dtype='<U9'),
#  267: array(['18-1-1', '18-1-2', '18-1-3', '18-2-1', '18-2-2', '18-2-3',
#         '18-3-1', '18-3-2', '18-3-3', '18-4-1', '18-4-2', '18-4-3'],
#        dtype='<U6'),
#  268: array(['3-0', '3-1-1', '3-1-2', '3-1-3', '3-2-1', '3-2-2', '3-2-3',
#         '3-3-1', '3-3-2', '3-3-3', '3-4-1', '3-4-2', '3-4-3'], dtype='<U5'),
#  269: array(['20-1-1', '20-1-2', '20-1-3', '20-2-1', '20-2-2', '20-2-3',
#         '20-3-1', '20-3-2', '20-3-3', '20-4-1', '20-4-2', '20-4-3',
#         '21+wt', '21-0-1', '21-0-2', '21-0-4', '21-1-1', '21-1-2',
#         '21-1-3', '21-2-1', '21-2-2', '21-2-3', '21-3-1', '21-3-2',
#         '21-3-3', '21-4-1', '21-4-2', '21-4-3', '23-0', '23-1-1', '23-1-2',
#         '23-1-3', '23-2-1', '23-2-2', '23-2-3', '23-3-1', '23-3-2',
#         '23-3-3', '23-4-1', '23-4-2', '23-4-3'], dtype='<U6'),
#  270: array(['6-0', '6-1-1', '6-1-2', '6-1-3', '6-2-1', '6-2-2', '6-2-3',
#         '6-3-1', '6-3-2', '6-3-3', '6-4-1', '6-4-2', '6-4-3'], dtype='<U5')}

# %%
write_loc = 'SequenceToCount/technical_replicates/'


with open(f'{write_loc}techRep_demultiplex.inp','w') as inp_f:
    for g,group in actual_groups.items():
        sample_list_name =  f'Group_{g+1:03}_Samples.txt'

        inp_f.write(f'{sample_list_name}\n')
    


    ### CREATE SBATCH FILE!!!
            
sbatch_name = f'techRep_demultiplex.sbatch'

with open(f'{write_loc}{sbatch_name}','w') as sbatch_f:

    sbatch_f.write(f"""#!/usr/bin/env bash
#SBATCH -J techRep_demultiplex
#SBATCH -p hns,dpetrov,normal,owners
#SBATCH -n 16
#SBATCH -N 1
#SBATCH -t 2-00:00
#SBATCH --array=1-{len(actual_groups.keys())}
#SBATCH --mem-per-cpu=2G
#SBATCH --requeue
#SBATCH -o SlurmFiles/slurm-%A_%a_%x.out
#SBATCH --mail-user=grantkinsler@gmail.com
#SBATCH --mail-type=END

sample_sheets=$(sed -n "$SLURM_ARRAY_TASK_ID"p techRep_demultiplex.inp)

module load python/3.6.1
module load biology
module load ncbi-blast+/2.7.1
python3 /home/groups/dpetrov/SOFTWARE/BarcodeCounter2-master_07272021update/barcodeCounter.py -fastqDir ../AllRawData/ -outputDir ../BarcodeCounts_technical_replicates/ -templateSeq ../Template_doubleBC_Read1First.txt -sample $sample_sheets -multiBCFasta ../Primers_noP.fasta -pairedEnd -useUMI -numThreads 32 -demultiplexOnly -useBowtie2 -bowtie2Path /home/groups/dpetrov/SOFTWARE/bowtie2-2.2.6_new/ -readLength 108
""")

    
for g,group in actual_groups.items():
    
    with open(f'{write_loc}Group_{g+1:03}_Samples.txt','w') as sample_f:
        this_group = samples[samples['sample'].isin(group)]
        
        for item in this_group[this_group.columns].values:
            sample_f.write(f'{item[0]}\t{item[1]}\t{item[2]}\t{item[3]}\n')
            
with open(f'{write_loc}AllSamples.txt','w') as sample_f:
    for g,group in actual_groups.items():
    
        this_group = samples[samples['sample'].isin(group)]
        
        for item in this_group[this_group.columns].values:
            sample_f.write(f'{item[0]}\t{item[1]}\t{item[2]}\t{item[3]}\n')

            

            
### Mapping Barcodes (in parallel), with UMIs
sbatch_name = f'techRep_map_barcodes.sbatch'

with open(f'{write_loc}{sbatch_name}','w') as sbatch_f:

    sbatch_f.write(f"""#!/usr/bin/env bash
#SBATCH -J techRep_map
#SBATCH -p hns,dpetrov,normal,owners
#SBATCH -n 16
#SBATCH -N 1
#SBATCH -t 2-00:00
#SBATCH --array=1-{len(actual_groups.keys())}
#SBATCH --mem-per-cpu=2G
#SBATCH --requeue
#SBATCH -o SlurmFiles/slurm-%A_%a_%x.out
#SBATCH --mail-user=grantkinsler@gmail.com
#SBATCH --mail-type=END

sample_sheets=$(sed -n "$SLURM_ARRAY_TASK_ID"p techRep_demultiplex.inp)

module load python/3.6.1
module load biology
module load ncbi-blast+/2.7.1
python3 /home/groups/dpetrov/SOFTWARE/BarcodeCounter2-master_07272021update/barcodeCounter.py -fastqDir ../AllRawData/ -outputDir ../BarcodeCounts_technical_replicates/ -templateSeq ../Template_doubleBC_Read1First.txt -sample $sample_sheets -multiBCFasta ../Primers_noP.fasta -pairedEnd -useUMI -numThreads 16 -skipSplitFastq -barcodeList ../500pool_noconstant_bothBCs_withSpikeIns.fasta -useBowtie2 -bowtie2Path /home/groups/dpetrov/SOFTWARE/bowtie2-2.2.6_new/ -readLength 108 -remapBarcodes
""")
    
    

    
### Final count (no re-mapping), with UMIs
sbatch_name = f'techRep_count_barcodes.sbatch'

with open(f'{write_loc}{sbatch_name}','w') as sbatch_f:

    sbatch_f.write(f"""#!/usr/bin/env bash
#SBATCH -J techRep_count
#SBATCH -p hns,dpetrov,normal,owners
#SBATCH -n 16
#SBATCH -N 1
#SBATCH -t 2-00:00
#SBATCH --array=1-1
#SBATCH --mem-per-cpu=2G
#SBATCH --requeue
#SBATCH -o SlurmFiles/slurm-%A_%a_%x.out
#SBATCH --mail-user=grantkinsler@gmail.com
#SBATCH --mail-type=END


module load python/3.6.1
module load biology
module load ncbi-blast+/2.7.1
python3 /home/groups/dpetrov/SOFTWARE/BarcodeCounter2-master_07272021update/barcodeCounter.py -fastqDir ../AllRawData/ -outputDir ../BarcodeCounts_technical_replicates/ -templateSeq ../Template_doubleBC_Read1First.txt -sample AllSamples.txt -multiBCFasta ../Primers_noP.fasta -pairedEnd -useUMI -numThreads 16 -skipSplitFastq -barcodeList ../500pool_noconstant_bothBCs_withSpikeIns.fasta -useBowtie2 -bowtie2Path /home/groups/dpetrov/SOFTWARE/bowtie2-2.2.6_new/ -readLength 108
""")

# %%
#### WITHOUT UMIs included!!!!

write_loc = 'SequenceToCount/umi_analysis/'

for g,group in actual_groups.items():
    
    with open(f'{write_loc}Group_{g+1:03}_Samples.txt','w') as sample_f:
        this_group = samples[samples['sample'].isin(group)]
        
        for item in this_group[this_group.columns].values:
            sample_f.write(f'{item[0]}\t{item[1]}\t{item[2]}\t{item[3]}\n')
            
with open(f'{write_loc}AllSamples.txt','w') as sample_f:
    for g,group in actual_groups.items():
    
        this_group = samples[samples['sample'].isin(group)]
        
        for item in this_group[this_group.columns].values:
            sample_f.write(f'{item[0]}\t{item[1]}\t{item[2]}\t{item[3]}\n')



### Mapping Barcodes (in parallel), WITHOUT UMIs!!!
sbatch_name = f'umi_analysis_map_barcodes.sbatch'

with open(f'{write_loc}{sbatch_name}','w') as sbatch_f:

    sbatch_f.write(f"""#!/usr/bin/env bash
#SBATCH -J umi_map
#SBATCH -p hns,dpetrov,normal,owners
#SBATCH -n 16
#SBATCH -N 1
#SBATCH -t 2-00:00
#SBATCH --array=1-{len(actual_groups.keys())}
#SBATCH --mem-per-cpu=2G
#SBATCH --requeue
#SBATCH -o SlurmFiles/slurm-%A_%a_%x.out
#SBATCH --mail-user=grantkinsler@gmail.com
#SBATCH --mail-type=END

sample_sheets=$(sed -n "$SLURM_ARRAY_TASK_ID"p techRep_demultiplex.inp)

module load python/3.6.1
module load biology
module load ncbi-blast+/2.7.1
python3 /home/groups/dpetrov/SOFTWARE/BarcodeCounter2-master_07272021update/barcodeCounter.py -fastqDir ../AllRawData/ -outputDir ../BarcodeCounts_umi_analysis/ -templateSeq ../Template_doubleBC_Read1First.txt -sample $sample_sheets -multiBCFasta ../Primers_noP.fasta -pairedEnd -numThreads 16 -skipSplitFastq -barcodeList ../500pool_noconstant_bothBCs_withSpikeIns.fasta -useBowtie2 -bowtie2Path /home/groups/dpetrov/SOFTWARE/bowtie2-2.2.6_new/ -readLength 108 -remapBarcodes
""")

### Final count (no re-mapping), WITHOUTTT UMIs

sbatch_name = f'umi_analysis_count_barcodes.sbatch'

with open(f'{write_loc}{sbatch_name}','w') as sbatch_f:

    sbatch_f.write(f"""#!/usr/bin/env bash
#SBATCH -J umi_count
#SBATCH -p hns,dpetrov,normal,owners
#SBATCH -n 16
#SBATCH -N 1
#SBATCH -t 2-00:00
#SBATCH --array=1-1
#SBATCH --mem-per-cpu=2G
#SBATCH --requeue
#SBATCH -o SlurmFiles/slurm-%A_%a_%x.out
#SBATCH --mail-user=grantkinsler@gmail.com
#SBATCH --mail-type=END


module load python/3.6.1
module load biology
module load ncbi-blast+/2.7.1
python3 /home/groups/dpetrov/SOFTWARE/BarcodeCounter2-master_07272021update/barcodeCounter.py -fastqDir ../AllRawData/ -outputDir ../BarcodeCounts_umi_analysis/ -templateSeq ../Template_doubleBC_Read1First.txt -sample AllSamples.txt -multiBCFasta ../Primers_noP.fasta -pairedEnd -numThreads 16 -skipSplitFastq -barcodeList ../500pool_noconstant_bothBCs_withSpikeIns.fasta -useBowtie2 -bowtie2Path /home/groups/dpetrov/SOFTWARE/bowtie2-2.2.6_new/ -readLength 108
""")

# %%
for g,group in actual_groups.items():
    
#     with open(f'Group_{g+1:03}_Samples.txt'):
    this_group = samples[samples['sample'].isin(group)]
        
    for item in this_group[this_group.columns].values:
        
        print(f'{item[0]}\t{item[1]}\t{item[2]}\t{item[3]}\n')
# Out:
# B0-DE1-PCRa	040418_Unindexed	F202	R302
#
# B0-DE1-PCRa	051118_Unindexed	F202	R302
#
# B0-DE2-PCRa	040418_Unindexed	F203	R303
#
# B0-DE2-PCRa	051118_Unindexed	F203	R303
#
# B0-DE2-PCRb	051118_Unindexed	F208	R302
#
# B0-DE2-PCRc	051118_Unindexed	F209	R302
#
# B0-DE3-PCRa	051118_Unindexed	F203	R302
#
# B0-DE4-PCRa	051118_Unindexed	F212	R302
#
# B1-DE1-PCRa	051118_Unindexed	F202	R308
#
# B2-DE1-PCRa	040418_Unindexed	F204	R304
#
# B2-DE1-PCRa	051118_Unindexed	F204	R304
#
# B2-DE1-PCRb	051118_Unindexed	F208	R304
#
# B2-DE2-PCRa	051118_Unindexed	F202	R304
#
# B2-DE3-PCRa	051118_Unindexed	F205	R304
#
# B2-DE4-PCRa	051118_Unindexed	F206	R304
#
# B3-DE1-PCRb	051118_Unindexed	F209	R305
#
# B4-DE1-PCRa	040418_Unindexed	F206	R306
#
# B4-DE1-PCRa	051118_Unindexed	F206	R306
#
# B4-DE2-PCRa	040418_Unindexed	F207	R307
#
# B4-DE2-PCRa	051118_Unindexed	F207	R307
#
# B4-DE2-PCRb	051118_Unindexed	F208	R306
#
# B4-DE3-PCRa	051118_Unindexed	F203	R306
#
# B4-DE4-PCRa	051118_Unindexed	F204	R306
#
# C0-DE1-PCRa	051118_Unindexed	F205	R302
#
# C0-DE1-PCRb	051118_Unindexed	F209	R303
#
# C0-DE2-PCRa	051118_Unindexed	F206	R302
#
# C1-DE1-PCRb	051118_Unindexed	F209	R306
#
# C2-DE1-PCRa	051118_Unindexed	F207	R304
#
# C2-DE2-PCRa	051118_Unindexed	F211	R304
#
# C3-DE1-PCRa	051118_Unindexed	F207	R308
#
# C4-DE1-PCRa	051118_Unindexed	F207	R306
#
# C4-DE2-PCRa	051118_Unindexed	F210	R306
#
# Tneg-DE1-PCRa	051118_Unindexed	F206	R308
#
# Tneg-DE2-PCRa	051118_Unindexed	F204	R302
#
# Y0-DE1-PCRa	051118_Unindexed	F212	R303
#
# Y0-DE2-PCRa	051118_Unindexed	F205	R303
#
# Y0-DE2-PCRb	051118_Unindexed	F208	R303
#
# Y0-DE3-PCRa	051118_Unindexed	F206	R303
#
# Y0-DE4-PCRa	051118_Unindexed	F207	R303
#
# Y1-DE1-PCRb	051118_Unindexed	F209	R307
#
# Y2-DE1-PCRa	040418_Unindexed	F205	R305
#
# Y2-DE1-PCRa	051118_Unindexed	F205	R305
#
# Y2-DE1-PCRb	051118_Unindexed	F208	R305
#
# Y2-DE2-PCRa	051118_Unindexed	F202	R305
#
# Y2-DE3-PCRa	051118_Unindexed	F203	R305
#
# Y2-DE4-PCRa	051118_Unindexed	F206	R305
#
# Y3-DE1-PCRa	040418_Unindexed	F208	R308
#
# Y3-DE1-PCRa	051118_Unindexed	F208	R308
#
# Y4-DE1-PCRa	051118_Unindexed	F202	R306
#
# Y4-DE1-PCRb	051118_Unindexed	F208	R307
#
# Y4-DE2-PCRa	051118_Unindexed	F210	R307
#
# Y4-DE3-PCRa	051118_Unindexed	F202	R307
#
# Y4-DE4-PCRa	051118_Unindexed	F203	R307
#
# Z0-DE1-PCRa	051118_Unindexed	F207	R302
#
# Z0-DE2-PCRa	051118_Unindexed	F204	R303
#
# Z1-DE1-PCRa	051118_Unindexed	F205	R308
#
# Z2-DE1-PCRa	051118_Unindexed	F207	R305
#
# Z2-DE1-PCRb	051118_Unindexed	F209	R304
#
# Z2-DE2-PCRa	051118_Unindexed	F211	R305
#
# Z3-DE1-PCRa	051118_Unindexed	F209	R308
#
# Z4-DE1-PCRa	051118_Unindexed	F204	R307
#
# Z4-DE2-PCRa	051118_Unindexed	F205	R307
#
# B3-DE1-PCRa	040418_Unindexed	F201	R301
#
# B3-DE1-PCRa	051118_Unindexed	F201	R301
#
# B3-DE1-PCRa	080618_Nextseq_N727S522	F210	R308
#
# B3-DE1-PCRa	082818_Hiseq_N727S522	F210	R308
#
# B3-DE1-PCRa	070418_diagonal_N727S522	F210	R308
#
# C1-DE1-PCRa	051118_Unindexed	F203	R308
#
# C1-DE1-PCRa	080618_Nextseq_N728S522	F211	R308
#
# C1-DE1-PCRa	082818_Hiseq_N728S522	F211	R308
#
# Y1-DE1-PCRa	051118_Unindexed	F204	R308
#
# Y1-DE1-PCRa	080618_Nextseq_N729S522	F212	R308
#
# Y1-DE1-PCRa	082818_Hiseq_N729S522	F212	R308
#
# E0-DE1-PCRb	080618_Nextseq_N719S513	F203	R304
#
# E0-DE1-PCRb	082818_Hiseq_N719S513	F203	R304
#
# E0-DE1-PCRb	070418_diagonal_N719S513	F203	R304
#
# E1-DE1-PCRa	080618_Nextseq_N720S515	F204	R302
#
# E1-DE1-PCRa	082818_Hiseq_N720S515	F204	R302
#
# E1-DE1-PCRa	070418_diagonal_N720S515	F204	R302
#
# P1-DE1-PCRa	080618_Nextseq_N721S516	F205	R303
#
# P1-DE1-PCRa	082818_Hiseq_N721S516	F205	R303
#
# P1-DE1-PCRa	070418_diagonal_N721S516	F205	R303
#
# GG1-DE1-PCRa	080618_Nextseq_N722S517	F206	R304
#
# GG1-DE1-PCRa	082818_Hiseq_N722S517	F206	R304
#
# GG1-DE1-PCRa	070418_diagonal_N722S517	F206	R304
#
# AA2-DE1-PCRa	080618_Nextseq_N723S518	F207	R305
#
# AA2-DE1-PCRa	082818_Hiseq_N723S518	F207	R305
#
# AA2-DE1-PCRa	070418_diagonal_N723S518	F207	R305
#
# K3-DE1-PCRa	080618_Nextseq_N724S520	F208	R306
#
# K3-DE1-PCRa	082818_Hiseq_N724S520	F208	R306
#
# K3-DE1-PCRa	070418_diagonal_N724S520	F208	R306
#
# G4-DE1-PCRa	080618_Nextseq_N726S521	F209	R307
#
# G4-DE1-PCRa	082818_Hiseq_N726S521	F209	R307
#
# G4-DE1-PCRa	070418_diagonal_N726S521	F212	R307
#
# A0-DE1-PCRb	080618_Nextseq_N716S513	F201	R304
#
# A0-DE1-PCRb	082818_Hiseq_N716S513	F201	R304
#
# GG0-DE1-PCRa	080618_Nextseq_N716S515	F201	R302
#
# GG0-DE1-PCRa	082818_Hiseq_N716S515	F201	R302
#
# J1-DE1-PCRa	080618_Nextseq_N716S516	F201	R303
#
# J1-DE1-PCRa	082818_Hiseq_N716S516	F201	R303
#
# A0-DE1-PCRa	080618_Nextseq_N716S517	F201	R301
#
# A0-DE1-PCRa	082818_Hiseq_N716S517	F201	R301
#
# I2-DE1-PCRa	080618_Nextseq_N716S518	F201	R305
#
# I2-DE1-PCRa	082818_Hiseq_N716S518	F201	R305
#
# D3-DE1-PCRa	080618_Nextseq_N716S520	F201	R306
#
# D3-DE1-PCRa	082818_Hiseq_N716S520	F201	R306
#
# BB3-DE1-PCRa	080618_Nextseq_N716S521	F201	R307
#
# BB3-DE1-PCRa	082818_Hiseq_N716S521	F201	R307
#
# K4-DE1-PCRa	080618_Nextseq_N716S522	F201	R308
#
# K4-DE1-PCRa	082818_Hiseq_N716S522	F201	R308
#
# D0-DE1-PCRb	080618_Nextseq_N718S513	F202	R304
#
# D0-DE1-PCRb	082818_Hiseq_N718S513	F202	R304
#
# A1-DE1-PCRa	080618_Nextseq_N718S515	F202	R302
#
# A1-DE1-PCRa	082818_Hiseq_N718S515	F202	R302
#
# K1-DE1-PCRa	080618_Nextseq_N718S516	F202	R303
#
# K1-DE1-PCRa	082818_Hiseq_N718S516	F202	R303
#
# D0-DE1-PCRa	080618_Nextseq_N718S517	F202	R301
#
# D0-DE1-PCRa	082818_Hiseq_N718S517	F202	R301
#
# J2-DE1-PCRa	080618_Nextseq_N718S518	F202	R305
#
# J2-DE1-PCRa	082818_Hiseq_N718S518	F202	R305
#
# E3-DE1-PCRa	080618_Nextseq_N718S520	F202	R306
#
# E3-DE1-PCRa	082818_Hiseq_N718S520	F202	R306
#
# CC3-DE1-PCRa	080618_Nextseq_N718S521	F202	R307
#
# CC3-DE1-PCRa	082818_Hiseq_N718S521	F202	R307
#
# L4-DE1-PCRa	080618_Nextseq_N718S522	F202	R308
#
# L4-DE1-PCRa	082818_Hiseq_N718S522	F202	R308
#
# D1-DE1-PCRa	080618_Nextseq_N719S515	F203	R302
#
# D1-DE1-PCRa	082818_Hiseq_N719S515	F203	R302
#
# L1-DE1-PCRa	080618_Nextseq_N719S516	F203	R303
#
# L1-DE1-PCRa	082818_Hiseq_N719S516	F203	R303
#
# E0-DE1-PCRa	080618_Nextseq_N719S517	F203	R301
#
# E0-DE1-PCRa	082818_Hiseq_N719S517	F203	R301
#
# K2-DE1-PCRa	080618_Nextseq_N719S518	F203	R305
#
# K2-DE1-PCRa	082818_Hiseq_N719S518	F203	R305
#
# F3-DE1-PCRa	080618_Nextseq_N719S520	F203	R306
#
# F3-DE1-PCRa	082818_Hiseq_N719S520	F203	R306
#
# DD3-DE1-PCRa	080618_Nextseq_N719S521	F203	R307
#
# DD3-DE1-PCRa	082818_Hiseq_N719S521	F203	R307
#
# O4-DE1-PCRa	080618_Nextseq_N719S522	F203	R308
#
# O4-DE1-PCRa	082818_Hiseq_N719S522	F203	R308
#
# F0-DE1-PCRb	080618_Nextseq_N720S513	F204	R304
#
# F0-DE1-PCRb	082818_Hiseq_N720S513	F204	R304
#
# O1-DE1-PCRa	080618_Nextseq_N720S516	F204	R303
#
# O1-DE1-PCRa	082818_Hiseq_N720S516	F204	R303
#
# F0-DE1-PCRa	080618_Nextseq_N720S517	F204	R301
#
# F0-DE1-PCRa	082818_Hiseq_N720S517	F204	R301
#
# L2-DE1-PCRa	080618_Nextseq_N720S518	F204	R305
#
# L2-DE1-PCRa	082818_Hiseq_N720S518	F204	R305
#
# G3-DE1-PCRa	080618_Nextseq_N720S520	F204	R306
#
# G3-DE1-PCRa	082818_Hiseq_N720S520	F204	R306
#
# GG3-DE1-PCRa	080618_Nextseq_N720S521	F204	R307
#
# GG3-DE1-PCRa	082818_Hiseq_N720S521	F204	R307
#
# P4-DE1-PCRa	080618_Nextseq_N720S522	F204	R308
#
# P4-DE1-PCRa	082818_Hiseq_N720S522	F204	R308
#
# I0-DE1-PCRa	080618_Nextseq_N721S513	F205	R301
#
# I0-DE1-PCRa	082818_Hiseq_N721S513	F205	R301
#
# G0-DE1-PCRa	080618_Nextseq_N721S515	F205	R302
#
# G0-DE1-PCRa	082818_Hiseq_N721S515	F205	R302
#
# DD1-DE1-PCRa	080618_Nextseq_N721S517	F205	R304
#
# DD1-DE1-PCRa	082818_Hiseq_N721S517	F205	R304
#
# O2-DE1-PCRa	080618_Nextseq_N721S518	F205	R305
#
# O2-DE1-PCRa	082818_Hiseq_N721S518	F205	R305
#
# H3-DE1-PCRa	080618_Nextseq_N721S520	F205	R306
#
# H3-DE1-PCRa	082818_Hiseq_N721S520	F205	R306
#
# A4-DE1-PCRa	080618_Nextseq_N721S521	F205	R307
#
# A4-DE1-PCRa	082818_Hiseq_N721S521	F205	R307
#
# AA4-DE1-PCRa	080618_Nextseq_N721S522	F205	R308
#
# AA4-DE1-PCRa	082818_Hiseq_N721S522	F205	R308
#
# L0-DE1-PCRa	080618_Nextseq_N722S513	F206	R301
#
# L0-DE1-PCRa	082818_Hiseq_N722S513	F206	R301
#
# H0-DE1-PCRa	080618_Nextseq_N722S515	F206	R302
#
# H0-DE1-PCRa	082818_Hiseq_N722S515	F206	R302
#
# AA1-DE1-PCRa	080618_Nextseq_N722S516	F206	R303
#
# AA1-DE1-PCRa	082818_Hiseq_N722S516	F206	R303
#
# P2-DE1-PCRa	080618_Nextseq_N722S518	F206	R305
#
# P2-DE1-PCRa	082818_Hiseq_N722S518	F206	R305
#
# I3-DE1-PCRa	080618_Nextseq_N722S520	F206	R306
#
# I3-DE1-PCRa	082818_Hiseq_N722S520	F206	R306
#
# D4-DE1-PCRa	080618_Nextseq_N722S521	F206	R307
#
# D4-DE1-PCRa	082818_Hiseq_N722S521	F206	R307
#
# BB4-DE1-PCRa	080618_Nextseq_N722S522	F206	R308
#
# BB4-DE1-PCRa	082818_Hiseq_N722S522	F206	R308
#
# O0-DE1-PCRa	080618_Nextseq_N723S513	F207	R301
#
# O0-DE1-PCRa	082818_Hiseq_N723S513	F207	R301
#
# J0-DE1-PCRa	080618_Nextseq_N723S515	F207	R302
#
# J0-DE1-PCRa	082818_Hiseq_N723S515	F207	R302
#
# BB1-DE1-PCRa	080618_Nextseq_N723S516	F207	R303
#
# BB1-DE1-PCRa	082818_Hiseq_N723S516	F207	R303
#
# A2-DE1-PCRa	080618_Nextseq_N723S517	F207	R304
#
# A2-DE1-PCRa	082818_Hiseq_N723S517	F207	R304
#
# J3-DE1-PCRa	080618_Nextseq_N723S520	F207	R306
#
# J3-DE1-PCRa	082818_Hiseq_N723S520	F207	R306
#
# E4-DE1-PCRa	080618_Nextseq_N723S521	F207	R307
#
# E4-DE1-PCRa	082818_Hiseq_N723S521	F207	R307
#
# CC4-DE1-PCRa	080618_Nextseq_N723S522	F207	R308
#
# CC4-DE1-PCRa	082818_Hiseq_N723S522	F207	R308
#
# P0-DE1-PCRa	080618_Nextseq_N724S513	F208	R301
#
# P0-DE1-PCRa	082818_Hiseq_N724S513	F208	R301
#
# K0-DE1-PCRa	080618_Nextseq_N724S515	F208	R302
#
# K0-DE1-PCRa	082818_Hiseq_N724S515	F208	R302
#
# CC1-DE1-PCRa	080618_Nextseq_N724S516	F208	R303
#
# CC1-DE1-PCRa	082818_Hiseq_N724S516	F208	R303
#
# D2-DE1-PCRa	080618_Nextseq_N724S517	F208	R304
#
# D2-DE1-PCRa	082818_Hiseq_N724S517	F208	R304
#
# BB2-DE1-PCRa	080618_Nextseq_N724S518	F208	R305
#
# BB2-DE1-PCRa	082818_Hiseq_N724S518	F208	R305
#
# F4-DE1-PCRa	080618_Nextseq_N724S521	F208	R307
#
# F4-DE1-PCRa	082818_Hiseq_N724S521	F208	R307
#
# DD4-DE1-PCRa	080618_Nextseq_N724S522	F208	R308
#
# DD4-DE1-PCRa	082818_Hiseq_N724S522	F208	R308
#
# AA0-DE1-PCRa	080618_Nextseq_N726S513	F209	R301
#
# AA0-DE1-PCRa	082818_Hiseq_N726S513	F209	R301
#
# F1-DE1-PCRa	080618_Nextseq_N726S515	F209	R302
#
# F1-DE1-PCRa	082818_Hiseq_N726S515	F209	R302
#
# G0-DE1-PCRb	080618_Nextseq_N726S516	F209	R303
#
# G0-DE1-PCRb	082818_Hiseq_N726S516	F209	R303
#
# E2-DE1-PCRa	080618_Nextseq_N726S517	F209	R304
#
# E2-DE1-PCRa	082818_Hiseq_N726S517	F209	R304
#
# CC2-DE1-PCRa	080618_Nextseq_N726S518	F209	R305
#
# CC2-DE1-PCRa	082818_Hiseq_N726S518	F209	R305
#
# L3-DE1-PCRa	080618_Nextseq_N726S520	F209	R306
#
# L3-DE1-PCRa	082818_Hiseq_N726S520	F209	R306
#
# GG4-DE1-PCRa	080618_Nextseq_N726S522	F209	R308
#
# GG4-DE1-PCRa	082818_Hiseq_N726S522	F209	R308
#
# BB0-DE1-PCRa	080618_Nextseq_N727S513	F210	R301
#
# BB0-DE1-PCRa	082818_Hiseq_N727S513	F210	R301
#
# G1-DE1-PCRa	080618_Nextseq_N727S515	F210	R302
#
# G1-DE1-PCRa	082818_Hiseq_N727S515	F210	R302
#
# H0-DE1-PCRb	080618_Nextseq_N727S516	F210	R303
#
# H0-DE1-PCRb	082818_Hiseq_N727S516	F210	R303
#
# F2-DE1-PCRa	080618_Nextseq_N727S517	F210	R304
#
# F2-DE1-PCRa	082818_Hiseq_N727S517	F210	R304
#
# DD2-DE1-PCRa	080618_Nextseq_N727S518	F210	R305
#
# DD2-DE1-PCRa	082818_Hiseq_N727S518	F210	R305
#
# O3-DE1-PCRa	080618_Nextseq_N727S520	F210	R306
#
# O3-DE1-PCRa	082818_Hiseq_N727S520	F210	R306
#
# H4-DE1-PCRa	080618_Nextseq_N727S521	F210	R307
#
# H4-DE1-PCRa	082818_Hiseq_N727S521	F210	R307
#
# CC0-DE1-PCRa	080618_Nextseq_N728S513	F211	R301
#
# CC0-DE1-PCRa	082818_Hiseq_N728S513	F211	R301
#
# H1-DE1-PCRa	080618_Nextseq_N728S515	F211	R302
#
# H1-DE1-PCRa	082818_Hiseq_N728S515	F211	R302
#
# J0-DE1-PCRb	080618_Nextseq_N728S516	F211	R303
#
# J0-DE1-PCRb	082818_Hiseq_N728S516	F211	R303
#
# G2-DE1-PCRa	080618_Nextseq_N728S517	F211	R304
#
# G2-DE1-PCRa	082818_Hiseq_N728S517	F211	R304
#
# GG2-DE1-PCRa	080618_Nextseq_N728S518	F211	R305
# GG2-DE1-PCRa	082818_Hiseq_N728S518	F211	R305
#
# P3-DE1-PCRa	080618_Nextseq_N728S520	F211	R306
#
# P3-DE1-PCRa	082818_Hiseq_N728S520	F211	R306
#
# I4-DE1-PCRa	080618_Nextseq_N728S521	F211	R307
#
# I4-DE1-PCRa	082818_Hiseq_N728S521	F211	R307
#
# DD0-DE1-PCRa	080618_Nextseq_N729S513	F212	R301
#
# DD0-DE1-PCRa	082818_Hiseq_N729S513	F212	R301
#
# I1-DE1-PCRa	080618_Nextseq_N729S515	F212	R302
#
# I1-DE1-PCRa	082818_Hiseq_N729S515	F212	R302
#
# K0-DE1-PCRb	080618_Nextseq_N729S516	F212	R303
#
# K0-DE1-PCRb	082818_Hiseq_N729S516	F212	R303
#
# H2-DE1-PCRa	080618_Nextseq_N729S517	F212	R304
#
# H2-DE1-PCRa	082818_Hiseq_N729S517	F212	R304
#
# A3-DE1-PCRa	080618_Nextseq_N729S518	F212	R305
#
# A3-DE1-PCRa	082818_Hiseq_N729S518	F212	R305
#
# AA3-DE1-PCRa	080618_Nextseq_N729S520	F212	R306
#
# AA3-DE1-PCRa	082818_Hiseq_N729S520	F212	R306
#
# J4-DE1-PCRa	080618_Nextseq_N729S521	F212	R307
#
# J4-DE1-PCRa	082818_Hiseq_N729S521	F212	R307
#
# EE0-DE1-PCRa	090118_Nextseq_N716S517	F201	R304
#
# EE0-DE1-PCRa	092518_lane1_Nextseq_N716S517	F201	R304
#
# EE0-DE1-PCRa	092518_lane2_Nextseq_N716S517	F201	R304
#
# EE0-DE1-PCRa	120118_NextseqHTP_N716S517	F201	R304
#
# EE1-DE1-PCRa	090118_Nextseq_N716S518	F201	R305
#
# EE1-DE1-PCRa	092518_lane1_Nextseq_N716S518	F201	R305
#
# EE1-DE1-PCRa	092518_lane2_Nextseq_N716S518	F201	R305
#
# EE1-DE1-PCRa	120118_NextseqHTP_N716S518	F201	R305
#
# EE2-DE1-PCRa	090118_Nextseq_N716S520	F201	R306
#
# EE2-DE1-PCRa	092518_lane1_Nextseq_N716S520	F201	R306
#
# EE2-DE1-PCRa	092518_lane2_Nextseq_N716S520	F201	R306
#
# EE2-DE1-PCRa	120118_NextseqHTP_N716S520	F201	R306
#
# EE3-DE1-PCRa	090118_Nextseq_N716S521	F201	R307
#
# EE3-DE1-PCRa	092518_lane1_Nextseq_N716S521	F201	R307
#
# EE3-DE1-PCRa	092518_lane2_Nextseq_N716S521	F201	R307
#
# EE3-DE1-PCRa	120118_NextseqHTP_N716S521	F201	R307
#
# EE4-DE1-PCRa	090118_Nextseq_N716S522	F201	R308
#
# EE4-DE1-PCRa	092518_lane1_Nextseq_N716S522	F201	R308
#
# EE4-DE1-PCRa	092518_lane2_Nextseq_N716S522	F201	R308
#
# EE4-DE1-PCRa	120118_NextseqHTP_N716S522	F201	R308
#
# FF0-DE1-PCRa	090118_Nextseq_N718S517	F202	R304
#
# FF0-DE1-PCRa	092518_lane1_Nextseq_N718S517	F202	R304
#
# FF0-DE1-PCRa	092518_lane2_Nextseq_N718S517	F202	R304
#
# FF0-DE1-PCRa	120118_NextseqHTP_N718S517	F202	R304
#
# FF1-DE1-PCRa	090118_Nextseq_N718S518	F202	R305
#
# FF1-DE1-PCRa	092518_lane1_Nextseq_N718S518	F202	R305
#
# FF1-DE1-PCRa	092518_lane2_Nextseq_N718S518	F202	R305
#
# FF1-DE1-PCRa	120118_NextseqHTP_N718S518	F202	R305
#
# FF2-DE1-PCRa	090118_Nextseq_N718S520	F202	R306
#
# FF2-DE1-PCRa	092518_lane1_Nextseq_N718S520	F202	R306
#
# FF2-DE1-PCRa	092518_lane2_Nextseq_N718S520	F202	R306
#
# FF2-DE1-PCRa	120118_NextseqHTP_N718S520	F202	R306
#
# FF3-DE1-PCRa	090118_Nextseq_N718S521	F202	R307
#
# FF3-DE1-PCRa	092518_lane1_Nextseq_N718S521	F202	R307
#
# FF3-DE1-PCRa	092518_lane2_Nextseq_N718S521	F202	R307
#
# FF3-DE1-PCRa	120118_NextseqHTP_N718S521	F202	R307
#
# FF4-DE1-PCRa	090118_Nextseq_N718S522	F202	R308
#
# FF4-DE1-PCRa	092518_lane1_Nextseq_N718S522	F202	R308
#
# FF4-DE1-PCRa	092518_lane2_Nextseq_N718S522	F202	R308
#
# FF4-DE1-PCRa	120118_NextseqHTP_N718S522	F202	R308
#
# M0-DE1-PCRa	090118_Nextseq_N719S517	F203	R304
#
# M0-DE1-PCRa	092518_lane1_Nextseq_N719S517	F203	R304
#
# M0-DE1-PCRa	092518_lane2_Nextseq_N719S517	F203	R304
#
# M0-DE1-PCRa	120118_NextseqHTP_N719S517	F203	R304
#
# M1-DE1-PCRa	090118_Nextseq_N719S518	F203	R305
#
# M1-DE1-PCRa	092518_lane1_Nextseq_N719S518	F203	R305
#
# M1-DE1-PCRa	092518_lane2_Nextseq_N719S518	F203	R305
#
# M1-DE1-PCRa	120118_NextseqHTP_N719S518	F203	R305
#
# M2-DE1-PCRa	090118_Nextseq_N719S520	F203	R306
#
# M2-DE1-PCRa	092518_lane1_Nextseq_N719S520	F203	R306
#
# M2-DE1-PCRa	092518_lane2_Nextseq_N719S520	F203	R306
#
# M2-DE1-PCRa	120118_NextseqHTP_N719S520	F203	R306
#
# M3-DE1-PCRa	090118_Nextseq_N719S521	F203	R307
#
# M3-DE1-PCRa	092518_lane1_Nextseq_N719S521	F203	R307
#
# M3-DE1-PCRa	092518_lane2_Nextseq_N719S521	F203	R307
#
# M3-DE1-PCRa	120118_NextseqHTP_N719S521	F203	R307
#
# M4-DE1-PCRa	090118_Nextseq_N719S522	F203	R308
#
# M4-DE1-PCRa	092518_lane1_Nextseq_N719S522	F203	R308
#
# M4-DE1-PCRa	092518_lane2_Nextseq_N719S522	F203	R308
#
# M4-DE1-PCRa	120118_NextseqHTP_N719S522	F203	R308
#
# N0-DE1-PCRa	090118_Nextseq_N720S517	F204	R304
#
# N0-DE1-PCRa	092518_lane1_Nextseq_N720S517	F204	R304
#
# N0-DE1-PCRa	092518_lane2_Nextseq_N720S517	F204	R304
#
# N0-DE1-PCRa	120118_NextseqHTP_N720S517	F204	R304
#
# N1-DE1-PCRa	090118_Nextseq_N720S518	F204	R305
#
# N1-DE1-PCRa	092518_lane1_Nextseq_N720S518	F204	R305
#
# N1-DE1-PCRa	092518_lane2_Nextseq_N720S518	F204	R305
#
# N1-DE1-PCRa	120118_NextseqHTP_N720S518	F204	R305
#
# N2-DE1-PCRa	090118_Nextseq_N720S520	F204	R306
#
# N2-DE1-PCRa	092518_lane1_Nextseq_N720S520	F204	R306
#
# N2-DE1-PCRa	092518_lane2_Nextseq_N720S520	F204	R306
#
# N2-DE1-PCRa	120118_NextseqHTP_N720S520	F204	R306
#
# N3-DE1-PCRa	090118_Nextseq_N720S521	F204	R307
#
# N3-DE1-PCRa	092518_lane1_Nextseq_N720S521	F204	R307
#
# N3-DE1-PCRa	092518_lane2_Nextseq_N720S521	F204	R307
#
# N3-DE1-PCRa	120118_NextseqHTP_N720S521	F204	R307
#
# N4-DE1-PCRa	090118_Nextseq_N720S522	F204	R308
#
# N4-DE1-PCRa	092518_lane1_Nextseq_N720S522	F204	R308
#
# N4-DE1-PCRa	092518_lane2_Nextseq_N720S522	F204	R308
#
# N4-DE1-PCRa	120118_NextseqHTP_N720S522	F204	R308
#
# Q0-DE1-PCRa	090118_Nextseq_N721S517	F205	R304
#
# Q0-DE1-PCRa	092518_lane1_Nextseq_N721S517	F205	R304
#
# Q0-DE1-PCRa	092518_lane2_Nextseq_N721S517	F205	R304
#
# Q0-DE1-PCRa	120118_NextseqHTP_N721S517	F205	R304
#
# Q1-DE1-PCRa	090118_Nextseq_N721S518	F205	R305
#
# Q1-DE1-PCRa	092518_lane1_Nextseq_N721S518	F205	R305
#
# Q1-DE1-PCRa	092518_lane2_Nextseq_N721S518	F205	R305
#
# Q1-DE1-PCRa	120118_NextseqHTP_N721S518	F205	R305
#
# Q2-DE1-PCRa	090118_Nextseq_N721S520	F205	R306
#
# Q2-DE1-PCRa	092518_lane1_Nextseq_N721S520	F205	R306
#
# Q2-DE1-PCRa	092518_lane2_Nextseq_N721S520	F205	R306
#
# Q2-DE1-PCRa	120118_NextseqHTP_N721S520	F205	R306
#
# Q3-DE1-PCRa	090118_Nextseq_N721S521	F205	R307
#
# Q3-DE1-PCRa	092518_lane1_Nextseq_N721S521	F205	R307
#
# Q3-DE1-PCRa	092518_lane2_Nextseq_N721S521	F205	R307
#
# Q3-DE1-PCRa	120118_NextseqHTP_N721S521	F205	R307
#
# Q4-DE1-PCRa	090118_Nextseq_N721S522	F205	R308
#
# Q4-DE1-PCRa	092518_lane1_Nextseq_N721S522	F205	R308
#
# Q4-DE1-PCRa	092518_lane2_Nextseq_N721S522	F205	R308
#
# Q4-DE1-PCRa	120118_NextseqHTP_N721S522	F205	R308
#
# R0-DE1-PCRa	090118_Nextseq_N722S517	F206	R304
#
# R0-DE1-PCRa	092518_lane1_Nextseq_N722S517	F206	R304
#
# R0-DE1-PCRa	092518_lane2_Nextseq_N722S517	F206	R304
#
# R0-DE1-PCRa	120118_NextseqHTP_N722S517	F206	R304
#
# R1-DE1-PCRa	090118_Nextseq_N722S518	F206	R305
#
# R1-DE1-PCRa	092518_lane1_Nextseq_N722S518	F206	R305
#
# R1-DE1-PCRa	092518_lane2_Nextseq_N722S518	F206	R305
#
# R1-DE1-PCRa	120118_NextseqHTP_N722S518	F206	R305
#
# R2-DE1-PCRa	090118_Nextseq_N722S520	F206	R306
#
# R2-DE1-PCRa	092518_lane1_Nextseq_N722S520	F206	R306
#
# R2-DE1-PCRa	092518_lane2_Nextseq_N722S520	F206	R306
#
# R2-DE1-PCRa	120118_NextseqHTP_N722S520	F206	R306
#
# R3-DE1-PCRa	090118_Nextseq_N722S521	F206	R307
#
# R3-DE1-PCRa	092518_lane1_Nextseq_N722S521	F206	R307
#
# R3-DE1-PCRa	092518_lane2_Nextseq_N722S521	F206	R307
#
# R3-DE1-PCRa	120118_NextseqHTP_N722S521	F206	R307
#
# R4-DE1-PCRa	090118_Nextseq_N722S522	F206	R308
#
# R4-DE1-PCRa	092518_lane1_Nextseq_N722S522	F206	R308
#
# R4-DE1-PCRa	092518_lane2_Nextseq_N722S522	F206	R308
#
# R4-DE1-PCRa	120118_NextseqHTP_N722S522	F206	R308
#
# S0-DE1-PCRa	090118_Nextseq_N723S517	F207	R304
#
# S0-DE1-PCRa	092518_lane1_Nextseq_N723S517	F207	R304
#
# S0-DE1-PCRa	092518_lane2_Nextseq_N723S517	F207	R304
#
# S0-DE1-PCRa	120118_NextseqHTP_N723S517	F207	R304
#
# X1-DE1-PCRa	090118_Nextseq_N723S517	F212	R304
#
# X1-DE1-PCRa	092518_lane1_Nextseq_N723S517	F212	R304
#
# X1-DE1-PCRa	092518_lane2_Nextseq_N723S517	F212	R304
#
# X1-DE1-PCRa	120118_NextseqHTP_N723S517	F212	R304
#
# S1-DE1-PCRa	090118_Nextseq_N723S518	F207	R305
#
# S1-DE1-PCRa	092518_lane1_Nextseq_N723S518	F207	R305
#
# S1-DE1-PCRa	092518_lane2_Nextseq_N723S518	F207	R305
#
# S1-DE1-PCRa	120118_NextseqHTP_N723S518	F207	R305
#
# S2-DE1-PCRa	090118_Nextseq_N723S520	F207	R306
#
# S2-DE1-PCRa	092518_lane1_Nextseq_N723S520	F207	R306
#
# S2-DE1-PCRa	092518_lane2_Nextseq_N723S520	F207	R306
#
# S2-DE1-PCRa	120118_NextseqHTP_N723S520	F207	R306
#
# S3-DE1-PCRa	090118_Nextseq_N723S521	F207	R307
#
# S3-DE1-PCRa	092518_lane1_Nextseq_N723S521	F207	R307
#
# S3-DE1-PCRa	092518_lane2_Nextseq_N723S521	F207	R307
#
# S3-DE1-PCRa	120118_NextseqHTP_N723S521	F207	R307
#
# S4-DE1-PCRa	090118_Nextseq_N723S522	F207	R308
#
# S4-DE1-PCRa	092518_lane1_Nextseq_N723S522	F207	R308
#
# S4-DE1-PCRa	092518_lane2_Nextseq_N723S522	F207	R308
#
# S4-DE1-PCRa	120118_NextseqHTP_N723S522	F207	R308
#
# T0-DE1-PCRa	090118_Nextseq_N724S517	F208	R304
#
# T0-DE1-PCRa	092518_lane1_Nextseq_N724S517	F208	R304
#
# T0-DE1-PCRa	092518_lane2_Nextseq_N724S517	F208	R304
#
# T0-DE1-PCRa	120118_NextseqHTP_N724S517	F208	R304
#
# T1-DE1-PCRa	090118_Nextseq_N724S518	F208	R305
#
# T1-DE1-PCRa	092518_lane1_Nextseq_N724S518	F208	R305
#
# T1-DE1-PCRa	092518_lane2_Nextseq_N724S518	F208	R305
#
# T1-DE1-PCRa	120118_NextseqHTP_N724S518	F208	R305
#
# T2-DE1-PCRa	090118_Nextseq_N724S520	F208	R306
#
# T2-DE1-PCRa	092518_lane1_Nextseq_N724S520	F208	R306
#
# T2-DE1-PCRa	092518_lane2_Nextseq_N724S520	F208	R306
#
# T2-DE1-PCRa	120118_NextseqHTP_N724S520	F208	R306
#
# T3-DE1-PCRa	090118_Nextseq_N724S521	F208	R307
#
# T3-DE1-PCRa	092518_lane1_Nextseq_N724S521	F208	R307
#
# T3-DE1-PCRa	092518_lane2_Nextseq_N724S521	F208	R307
#
# T3-DE1-PCRa	120118_NextseqHTP_N724S521	F208	R307
#
# T4-DE1-PCRa	090118_Nextseq_N724S522	F208	R308
#
# T4-DE1-PCRa	092518_lane1_Nextseq_N724S522	F208	R308
#
# T4-DE1-PCRa	092518_lane2_Nextseq_N724S522	F208	R308
#
# T4-DE1-PCRa	120118_NextseqHTP_N724S522	F208	R308
#
# U0-DE1-PCRa	090118_Nextseq_N726S517	F209	R304
#
# U0-DE1-PCRa	092518_lane1_Nextseq_N726S517	F209	R304
#
# U0-DE1-PCRa	092518_lane2_Nextseq_N726S517	F209	R304
#
# U0-DE1-PCRa	120118_NextseqHTP_N726S517	F209	R304
#
# U1-DE1-PCRa	090118_Nextseq_N726S518	F209	R305
#
# U1-DE1-PCRa	092518_lane1_Nextseq_N726S518	F209	R305
#
# U1-DE1-PCRa	092518_lane2_Nextseq_N726S518	F209	R305
#
# U1-DE1-PCRa	120118_NextseqHTP_N726S518	F209	R305
#
# U2-DE1-PCRa	090118_Nextseq_N726S520	F209	R306
#
# U2-DE1-PCRa	092518_lane1_Nextseq_N726S520	F209	R306
#
# U2-DE1-PCRa	092518_lane2_Nextseq_N726S520	F209	R306
#
# U2-DE1-PCRa	120118_NextseqHTP_N726S520	F209	R306
#
# U3-DE1-PCRa	090118_Nextseq_N726S521	F209	R307
#
# U3-DE1-PCRa	092518_lane1_Nextseq_N726S521	F209	R307
#
# U3-DE1-PCRa	092518_lane2_Nextseq_N726S521	F209	R307
#
# U3-DE1-PCRa	120118_NextseqHTP_N726S521	F209	R307
#
# U4-DE1-PCRa	090118_Nextseq_N726S522	F209	R308
#
# U4-DE1-PCRa	092518_lane1_Nextseq_N726S522	F209	R308
#
# U4-DE1-PCRa	092518_lane2_Nextseq_N726S522	F209	R308
#
# U4-DE1-PCRa	120118_NextseqHTP_N726S522	F209	R308
#
# V0-DE1-PCRa	090118_Nextseq_N727S517	F210	R304
#
# V0-DE1-PCRa	092518_lane1_Nextseq_N727S517	F210	R304
#
# V0-DE1-PCRa	092518_lane2_Nextseq_N727S517	F210	R304
#
# V0-DE1-PCRa	120118_NextseqHTP_N727S517	F210	R304
#
# V1-DE1-PCRa	090118_Nextseq_N727S518	F210	R305
#
# V1-DE1-PCRa	092518_lane1_Nextseq_N727S518	F210	R305
#
# V1-DE1-PCRa	092518_lane2_Nextseq_N727S518	F210	R305
#
# V1-DE1-PCRa	120118_NextseqHTP_N727S518	F210	R305
#
# V2-DE1-PCRa	090118_Nextseq_N727S520	F210	R306
#
# V2-DE1-PCRa	092518_lane1_Nextseq_N727S520	F210	R306
#
# V2-DE1-PCRa	092518_lane2_Nextseq_N727S520	F210	R306
#
# V2-DE1-PCRa	120118_NextseqHTP_N727S520	F210	R306
#
# V3-DE1-PCRa	090118_Nextseq_N727S521	F210	R307
#
# V3-DE1-PCRa	092518_lane1_Nextseq_N727S521	F210	R307
#
# V3-DE1-PCRa	092518_lane2_Nextseq_N727S521	F210	R307
#
# V3-DE1-PCRa	120118_NextseqHTP_N727S521	F210	R307
#
# V4-DE1-PCRa	090118_Nextseq_N727S522	F210	R308
#
# V4-DE1-PCRa	092518_lane1_Nextseq_N727S522	F210	R308
#
# V4-DE1-PCRa	092518_lane2_Nextseq_N727S522	F210	R308
#
# V4-DE1-PCRa	120118_NextseqHTP_N727S522	F210	R308
#
# W0-DE1-PCRa	090118_Nextseq_N728S517	F211	R304
#
# W0-DE1-PCRa	092518_lane1_Nextseq_N728S517	F211	R304
#
# W0-DE1-PCRa	092518_lane2_Nextseq_N728S517	F211	R304
#
# W0-DE1-PCRa	120118_NextseqHTP_N728S517	F211	R304
#
# W1-DE1-PCRa	090118_Nextseq_N728S518	F211	R305
#
# W1-DE1-PCRa	092518_lane1_Nextseq_N728S518	F211	R305
#
# W1-DE1-PCRa	092518_lane2_Nextseq_N728S518	F211	R305
#
# W1-DE1-PCRa	120118_NextseqHTP_N728S518	F211	R305
#
# W2-DE1-PCRa	090118_Nextseq_N728S520	F211	R306
#
# W2-DE1-PCRa	092518_lane1_Nextseq_N728S520	F211	R306
#
# W2-DE1-PCRa	092518_lane2_Nextseq_N728S520	F211	R306
#
# W2-DE1-PCRa	120118_NextseqHTP_N728S520	F211	R306
#
# W3-DE1-PCRa	090118_Nextseq_N728S521	F211	R307
#
# W3-DE1-PCRa	092518_lane1_Nextseq_N728S521	F211	R307
#
# W3-DE1-PCRa	092518_lane2_Nextseq_N728S521	F211	R307
#
# W3-DE1-PCRa	120118_NextseqHTP_N728S521	F211	R307
#
# W4-DE1-PCRa	090118_Nextseq_N728S522	F211	R308
#
# W4-DE1-PCRa	092518_lane1_Nextseq_N728S522	F211	R308
#
# W4-DE1-PCRa	092518_lane2_Nextseq_N728S522	F211	R308
#
# W4-DE1-PCRa	120118_NextseqHTP_N728S522	F211	R308
#
# X0-DE1-PCRa	090118_Nextseq_N729S517	F212	R304
#
# X0-DE1-PCRa	092518_lane1_Nextseq_N729S517	F212	R304
#
# X0-DE1-PCRa	092518_lane2_Nextseq_N729S517	F212	R304
#
# X0-DE1-PCRa	120118_NextseqHTP_N729S517	F212	R304
#
# X2-DE1-PCRa	090118_Nextseq_N729S520	F212	R306
#
# X2-DE1-PCRa	092518_lane1_Nextseq_N729S520	F212	R306
#
# X2-DE1-PCRa	092518_lane2_Nextseq_N729S520	F212	R306
#
# X2-DE1-PCRa	120118_NextseqHTP_N729S520	F212	R306
#
# X3-DE1-PCRa	090118_Nextseq_N729S521	F212	R307
#
# X3-DE1-PCRa	092518_lane1_Nextseq_N729S521	F212	R307
#
# X3-DE1-PCRa	092518_lane2_Nextseq_N729S521	F212	R307
#
# X3-DE1-PCRa	120118_NextseqHTP_N729S521	F212	R307
#
# X4-DE1-PCRa	090118_Nextseq_N729S522	F212	R308
#
# X4-DE1-PCRa	092518_lane1_Nextseq_N729S522	F212	R308
#
# X4-DE1-PCRa	092518_lane2_Nextseq_N729S522	F212	R308
#
# X4-DE1-PCRa	120118_NextseqHTP_N729S522	F212	R308
#
# 1.4%-T0	090519_HiSeqX_N716S513	F201	R301
#
# 1.5%-T0	090519_HiSeqX_N716S515	F201	R302
#
# 1.6%-T0	090519_HiSeqX_N716S516	F201	R303
#
# 1.7%-T0	090519_HiSeqX_N716S517	F201	R304
#
# 1.8%-T0	090519_HiSeqX_N716S518	F201	R305
#
# 2.5%-T0	090519_HiSeqX_N716S520	F201	R306
#
# Ben0.4-T0	090519_HiSeqX_N716S521	F201	R307
#
# Ben2-T0	090519_HiSeqX_N716S522	F201	R308
#
# 1.4%-R1-T1	090519_HiSeqX_N718S513	F202	R301
#
# 1.5%-R1-T1	090519_HiSeqX_N718S515	F202	R302
#
# 1.6%-R1-T1	090519_HiSeqX_N718S516	F202	R303
#
# 1.7%-R1-T1	090519_HiSeqX_N718S517	F202	R304
#
# 1.8%-R1-T1	090519_HiSeqX_N718S518	F202	R305
#
# 2.5%-R1-T1	090519_HiSeqX_N718S520	F202	R306
#
# Ben0.4-R1-T1	090519_HiSeqX_N718S521	F202	R307
#
# Ben2-R1-T1	090519_HiSeqX_N718S522	F202	R308
#
# 1.4%-R1-T2	090519_HiSeqX_N719S513	F203	R301
#
# 1.5%-R1-T2	090519_HiSeqX_N719S515	F203	R302
#
# 1.6%-R1-T2	090519_HiSeqX_N719S516	F203	R303
#
# 1.7%-R1-T2	090519_HiSeqX_N719S517	F203	R304
#
# 1.8%-R1-T2	090519_HiSeqX_N719S518	F203	R305
#
# 2.5%-R1-T2	090519_HiSeqX_N719S520	F203	R306
#
# Ben0.4-R1-T2	090519_HiSeqX_N719S521	F203	R307
#
# Ben2-R1-T2	090519_HiSeqX_N719S522	F203	R308
#
# 1.4%-R1-T3	090519_HiSeqX_N720S513	F204	R301
#
# 1.5%-R1-T3	090519_HiSeqX_N720S515	F204	R302
#
# 1.6%-R1-T3	090519_HiSeqX_N720S516	F204	R303
#
# 1.7%-R1-T3	090519_HiSeqX_N720S517	F204	R304
# 1.8%-R1-T3	090519_HiSeqX_N720S518	F204	R305
#
# 2.5%-R1-T3	090519_HiSeqX_N720S520	F204	R306
#
# Ben0.4-R1-T3	090519_HiSeqX_N720S521	F204	R307
#
# Ben2-R1-T3	090519_HiSeqX_N720S522	F204	R308
#
# 1.4%-R1-T4	090519_HiSeqX_N721S513	F205	R301
#
# 1.5%-R1-T4	090519_HiSeqX_N721S515	F205	R302
#
# 1.6%-R1-T4	090519_HiSeqX_N721S516	F205	R303
#
# 1.7%-R1-T4	090519_HiSeqX_N721S517	F205	R304
#
# 1.8%-R1-T4	090519_HiSeqX_N721S518	F205	R305
#
# 2.5%-R1-T4	090519_HiSeqX_N721S520	F205	R306
#
# Ben0.4-R1-T4	090519_HiSeqX_N721S521	F205	R307
#
# Ben2-R1-T4	090519_HiSeqX_N721S522	F205	R308
#
# 1.4%-R2-T1	090519_HiSeqX_N722S513	F206	R301
#
# 1.5%-R2-T1	090519_HiSeqX_N722S515	F206	R302
#
# 1.6%-R2-T1	090519_HiSeqX_N722S516	F206	R303
#
# 1.7%-R2-T1	090519_HiSeqX_N722S517	F206	R304
#
# 1.8%-R2-T1	090519_HiSeqX_N722S518	F206	R305
#
# 2.5%-R2-T1	090519_HiSeqX_N722S520	F206	R306
#
# Ben0.4-R2-T1	090519_HiSeqX_N722S521	F206	R307
#
# Ben2-R2-T1	090519_HiSeqX_N722S522	F206	R308
#
# 1.4%-R2-T2	090519_HiSeqX_N723S513	F207	R301
#
# 1.5%-R2-T2	090519_HiSeqX_N723S515	F207	R302
#
# 1.6%-R2-T2	090519_HiSeqX_N723S516	F207	R303
#
# 1.7%-R2-T2	090519_HiSeqX_N723S517	F207	R304
#
# 1.8%-R2-T2	090519_HiSeqX_N723S518	F207	R305
#
# 2.5%-R2-T2	090519_HiSeqX_N723S520	F207	R306
#
# Ben0.4-R2-T2	090519_HiSeqX_N723S521	F207	R307
#
# Ben2-R2-T2	090519_HiSeqX_N723S522	F207	R308
#
# 1.4%-R2-T3	090519_HiSeqX_N724S513	F208	R301
#
# 1.5%-R2-T3	090519_HiSeqX_N724S515	F208	R302
#
# 1.6%-R2-T3	090519_HiSeqX_N724S516	F208	R303
#
# 1.7%-R2-T3	090519_HiSeqX_N724S517	F208	R304
#
# 1.8%-R2-T3	090519_HiSeqX_N724S518	F208	R305
#
# 2.5%-R2-T3	090519_HiSeqX_N724S520	F208	R306
#
# Ben0.4-R2-T3	090519_HiSeqX_N724S521	F208	R307
#
# Ben2-R2-T3	090519_HiSeqX_N724S522	F208	R308
#
# 1.4%-R2-T4	090519_HiSeqX_N726S513	F209	R301
#
# 1.5%-R2-T4	090519_HiSeqX_N726S515	F209	R302
#
# 1.6%-R2-T4	090519_HiSeqX_N726S516	F209	R303
#
# 1.7%-R2-T4	090519_HiSeqX_N726S517	F209	R304
#
# 1.8%-R2-T4	090519_HiSeqX_N726S518	F209	R305
#
# 2.5%-R2-T4	090519_HiSeqX_N726S520	F209	R306
#
# Ben0.4-R2-T4	090519_HiSeqX_N726S521	F209	R307
#
# Ben2-R2-T4	090519_HiSeqX_N726S522	F209	R308
#
# Ben10-T0	090519_HiSeqX_N727S513	F210	R301
#
# Ben10-R1-T1	090519_HiSeqX_N727S515	F210	R302
#
# Ben10-R1-T2	090519_HiSeqX_N727S516	F210	R303
#
# Ben10-R1-T3	090519_HiSeqX_N727S517	F210	R304
#
# Ben10-R1-T4	090519_HiSeqX_N727S518	F210	R305
#
# Ben10-R2-T1	090519_HiSeqX_N728S515	F211	R302
#
# Ben10-R2-T2	090519_HiSeqX_N728S516	F211	R303
#
# Ben10-R2-T3	090519_HiSeqX_N728S517	F211	R304
#
# Ben10-R2-T4	090519_HiSeqX_N728S518	F211	R305
#
# A0-DE2-PCRa	121318_lane1_N716S513	F201	R301
#
# A4-DE1-PCRb	121318_lane1_N718S515	F202	R302
#
# D1-DE1-PCRb	121318_lane1_N719S516	F203	R303
#
# E0-DE2-PCRa	121318_lane1_N720S517	F204	R304
#
# E4-DE1-PCRb	121318_lane1_N721S518	F205	R305
#
# F3-DE1-PCRb	121318_lane1_N722S520	F206	R306
#
# B2-DE1-PCRc	121318_lane1_N723S521	F207	R307
#
# C0-DE1-PCRc	121318_lane1_N724S522	F208	R308
#
# A1-DE1-PCRb	121318_lane2_N716S513	F201	R301
#
# Tneg-DE3-PCRa	121318_lane2_N718S515	F202	R302
#
# D2-DE1-PCRb	121318_lane2_N719S516	F203	R303
#
# E1-DE2-PCRa	121318_lane2_N720S517	F204	R304
#
# F0-DE2-PCRa	121318_lane2_N721S518	F205	R305
#
# F4-DE1-PCRb	121318_lane2_N722S520	F206	R306
#
# B3-DE1-PCRc	121318_lane2_N723S521	F207	R307
#
# C2-DE3-PCRb	121318_lane2_N724S522	F208	R308
#
# A2-DE1-PCRb	121318_lane3_N716S513	F201	R301
#
# B1-DE2-PCRa	121318_lane3_N718S515	F202	R302
#
# D3-DE1-PCRb	121318_lane3_N719S516	F203	R303
#
# E2-DE1-PCRb	121318_lane3_N720S517	F204	R304
#
# F1-DE1-PCRb	121318_lane3_N721S518	F205	R305
#
# C2-DE3-PCRa	121318_lane3_N722S520	F206	R306
#
# B4-DE5-PCRa	121318_lane3_N723S521	F207	R307
#
# C3-DE2-PCRa	121318_lane3_N724S522	F208	R308
#
# A3-DE1-PCRb	121318_lane4_N716S513	F201	R301
#
# D0-DE2-PCRa	121318_lane4_N718S515	F202	R302
#
# D4-DE1-PCRb	121318_lane4_N719S516	F203	R303
#
# E3-DE1-PCRb	121318_lane4_N720S517	F204	R304
#
# F2-DE1-PCRb	121318_lane4_N721S518	F205	R305
#
# C4-DE3-PCRa	121318_lane4_N722S520	F206	R306
#
# C1-DE1-PCRc	121318_lane4_N723S521	F207	R307
#
# C4-DE3-PCRb	121318_lane4_N724S522	F208	R308
#
# 13-0	Experiment13-15_Unindexed	F201	R301
#
# 13-0_pool	Experiment13-15_Unindexed	F201	R302
#
# 13-1-1	Experiment13-15_Unindexed	F201	R303
#
# 13-1-2	Experiment13-15_Unindexed	F201	R304
#
# 13-1-3	Experiment13-15_Unindexed	F201	R305
#
# 13-2-1	Experiment13-15_Unindexed	F201	R306
#
# 13-2-2	Experiment13-15_Unindexed	F201	R307
#
# 13-2-3	Experiment13-15_Unindexed	F201	R308
#
# 13-3-1	Experiment13-15_Unindexed	F202	R301
#
# 13-3-2	Experiment13-15_Unindexed	F202	R302
#
# 13-3-3	Experiment13-15_Unindexed	F202	R303
#
# 13-4-1	Experiment13-15_Unindexed	F202	R304
#
# 13-4-2	Experiment13-15_Unindexed	F202	R305
#
# 13-4-3	Experiment13-15_Unindexed	F202	R306
#
# 18-1-1	Experiment18-19_Unindexed	F201	R301
#
# 18-1-2	Experiment18-19_Unindexed	F201	R302
#
# 18-1-3	Experiment18-19_Unindexed	F201	R303
#
# 18-2-1	Experiment18-19_Unindexed	F201	R304
#
# 18-2-2	Experiment18-19_Unindexed	F201	R305
#
# 18-2-3	Experiment18-19_Unindexed	F201	R306
#
# 18-3-1	Experiment18-19_Unindexed	F201	R307
#
# 18-3-2	Experiment18-19_Unindexed	F201	R308
#
# 18-3-3	Experiment18-19_Unindexed	F202	R301
#
# 18-4-1	Experiment18-19_Unindexed	F202	R302
#
# 18-4-2	Experiment18-19_Unindexed	F202	R303
#
# 18-4-3	Experiment18-19_Unindexed	F202	R304
#
# 3-0	Experiment1and3_Unindexed	F204	R301
#
# 3-1-1	Experiment1and3_Unindexed	F203	R302
#
# 3-1-2	Experiment1and3_Unindexed	F204	R302
#
# 3-1-3	Experiment1and3_Unindexed	F202	R305
#
# 3-2-1	Experiment1and3_Unindexed	F206	R301
#
# 3-2-2	Experiment1and3_Unindexed	F204	R305
#
# 3-2-3	Experiment1and3_Unindexed	F205	R305
#
# 3-3-1	Experiment1and3_Unindexed	F206	R305
#
# 3-3-2	Experiment1and3_Unindexed	F207	R305
#
# 3-3-3	Experiment1and3_Unindexed	F201	R306
#
# 3-4-1	Experiment1and3_Unindexed	F202	R306
#
# 3-4-2	Experiment1and3_Unindexed	F203	R306
#
# 3-4-3	Experiment1and3_Unindexed	F204	R306
#
# 20-1-1	Experiment20-23_Unindexed	F201	R301
#
# 20-1-2	Experiment20-23_Unindexed	F201	R302
#
# 20-1-3	Experiment20-23_Unindexed	F201	R303
#
# 20-2-1	Experiment20-23_Unindexed	F201	R304
#
# 20-2-2	Experiment20-23_Unindexed	F201	R305
#
# 20-2-3	Experiment20-23_Unindexed	F201	R306
#
# 20-3-1	Experiment20-23_Unindexed	F201	R307
#
# 20-3-2	Experiment20-23_Unindexed	F201	R308
#
# 20-3-3	Experiment20-23_Unindexed	F202	R301
#
# 20-4-1	Experiment20-23_Unindexed	F202	R302
#
# 20-4-2	Experiment20-23_Unindexed	F202	R303
#
# 20-4-3	Experiment20-23_Unindexed	F202	R304
#
# 21-0-1	Experiment20-23_Unindexed	F207	R302
#
# 21-0-2	Experiment20-23_Unindexed	F207	R303
#
# 21-0-4	Experiment20-23_Unindexed	F207	R304
#
# 21-1-1	Experiment20-23_Unindexed	F202	R305
#
# 21-1-2	Experiment20-23_Unindexed	F202	R306
#
# 21-1-3	Experiment20-23_Unindexed	F202	R307
#
# 21-2-1	Experiment20-23_Unindexed	F202	R308
#
# 21-2-2	Experiment20-23_Unindexed	F204	R301
#
# 21-2-3	Experiment20-23_Unindexed	F204	R302
#
# 21-3-1	Experiment20-23_Unindexed	F204	R303
#
# 21-3-2	Experiment20-23_Unindexed	F204	R304
#
# 21-3-3	Experiment20-23_Unindexed	F204	R305
#
# 21-4-1	Experiment20-23_Unindexed	F204	R306
#
# 21-4-2	Experiment20-23_Unindexed	F204	R307
#
# 21-4-3	Experiment20-23_Unindexed	F204	R308
#
# 21+wt	Experiment20-23_Unindexed	F207	R301
#
# 23-0	Experiment20-23_Unindexed	F207	R305
#
# 23-1-1	Experiment20-23_Unindexed	F208	R301
#
# 23-1-2	Experiment20-23_Unindexed	F207	R306
#
# 23-1-3	Experiment20-23_Unindexed	F207	R307
#
# 23-2-1	Experiment20-23_Unindexed	F207	R308
#
# 23-2-2	Experiment20-23_Unindexed	F205	R301
#
# 23-2-3	Experiment20-23_Unindexed	F205	R302
#
# 23-3-1	Experiment20-23_Unindexed	F205	R303
#
# 23-3-2	Experiment20-23_Unindexed	F205	R304
#
# 23-3-3	Experiment20-23_Unindexed	F205	R305
#
# 23-4-1	Experiment20-23_Unindexed	F205	R306
#
# 23-4-2	Experiment20-23_Unindexed	F205	R307
#
# 23-4-3	Experiment20-23_Unindexed	F205	R308
#
# 6-0	Experiment6-8_Unindexed	F206	R304
#
# 6-1-1	Experiment6-8_Unindexed	F206	R305
#
# 6-1-2	Experiment6-8_Unindexed	F206	R306
#
# 6-1-3	Experiment6-8_Unindexed	F206	R307
#
# 6-2-1	Experiment6-8_Unindexed	F201	R301
#
# 6-2-2	Experiment6-8_Unindexed	F201	R302
#
# 6-2-3	Experiment6-8_Unindexed	F201	R303
#
# 6-3-1	Experiment6-8_Unindexed	F201	R304
#
# 6-3-2	Experiment6-8_Unindexed	F201	R305
#
# 6-3-3	Experiment6-8_Unindexed	F201	R306
#
# 6-4-1	Experiment6-8_Unindexed	F201	R307
#
# 6-4-2	Experiment6-8_Unindexed	F202	R301
#
# 6-4-3	Experiment6-8_Unindexed	F202	R302

# %%
this_group[this_group.columns].values
# Out:
# array([['B0-DE1-PCRa', '040418_Unindexed', 'F202', 'R302'],
#        ['B0-DE1-PCRa', '051118_Unindexed', 'F202', 'R302'],
#        ['B0-DE2-PCRa', '040418_Unindexed', 'F203', 'R303'],
#        ['B0-DE2-PCRa', '051118_Unindexed', 'F203', 'R303'],
#        ['B0-DE2-PCRb', '051118_Unindexed', 'F208', 'R302'],
#        ['B0-DE2-PCRc', '051118_Unindexed', 'F209', 'R302'],
#        ['B0-DE3-PCRa', '051118_Unindexed', 'F203', 'R302'],
#        ['B0-DE4-PCRa', '051118_Unindexed', 'F212', 'R302'],
#        ['B1-DE1-PCRa', '051118_Unindexed', 'F202', 'R308'],
#        ['B2-DE1-PCRa', '040418_Unindexed', 'F204', 'R304'],
#        ['B2-DE1-PCRa', '051118_Unindexed', 'F204', 'R304'],
#        ['B2-DE1-PCRb', '051118_Unindexed', 'F208', 'R304'],
#        ['B2-DE2-PCRa', '051118_Unindexed', 'F202', 'R304'],
#        ['B2-DE3-PCRa', '051118_Unindexed', 'F205', 'R304'],
#        ['B2-DE4-PCRa', '051118_Unindexed', 'F206', 'R304'],
#        ['B3-DE1-PCRb', '051118_Unindexed', 'F209', 'R305'],
#        ['B4-DE1-PCRa', '040418_Unindexed', 'F206', 'R306'],
#        ['B4-DE1-PCRa', '051118_Unindexed', 'F206', 'R306'],
#        ['B4-DE2-PCRa', '040418_Unindexed', 'F207', 'R307'],
#        ['B4-DE2-PCRa', '051118_Unindexed', 'F207', 'R307'],
#        ['B4-DE2-PCRb', '051118_Unindexed', 'F208', 'R306'],
#        ['B4-DE3-PCRa', '051118_Unindexed', 'F203', 'R306'],
#        ['B4-DE4-PCRa', '051118_Unindexed', 'F204', 'R306'],
#        ['C0-DE1-PCRa', '051118_Unindexed', 'F205', 'R302'],
#        ['C0-DE1-PCRb', '051118_Unindexed', 'F209', 'R303'],
#        ['C0-DE2-PCRa', '051118_Unindexed', 'F206', 'R302'],
#        ['C1-DE1-PCRb', '051118_Unindexed', 'F209', 'R306'],
#        ['C2-DE1-PCRa', '051118_Unindexed', 'F207', 'R304'],
#        ['C2-DE2-PCRa', '051118_Unindexed', 'F211', 'R304'],
#        ['C3-DE1-PCRa', '051118_Unindexed', 'F207', 'R308'],
#        ['C4-DE1-PCRa', '051118_Unindexed', 'F207', 'R306'],
#        ['C4-DE2-PCRa', '051118_Unindexed', 'F210', 'R306'],
#        ['Tneg-DE1-PCRa', '051118_Unindexed', 'F206', 'R308'],
#        ['Tneg-DE2-PCRa', '051118_Unindexed', 'F204', 'R302'],
#        ['Y0-DE1-PCRa', '051118_Unindexed', 'F212', 'R303'],
#        ['Y0-DE2-PCRa', '051118_Unindexed', 'F205', 'R303'],
#        ['Y0-DE2-PCRb', '051118_Unindexed', 'F208', 'R303'],
#        ['Y0-DE3-PCRa', '051118_Unindexed', 'F206', 'R303'],
#        ['Y0-DE4-PCRa', '051118_Unindexed', 'F207', 'R303'],
#        ['Y1-DE1-PCRb', '051118_Unindexed', 'F209', 'R307'],
#        ['Y2-DE1-PCRa', '040418_Unindexed', 'F205', 'R305'],
#        ['Y2-DE1-PCRa', '051118_Unindexed', 'F205', 'R305'],
#        ['Y2-DE1-PCRb', '051118_Unindexed', 'F208', 'R305'],
#        ['Y2-DE2-PCRa', '051118_Unindexed', 'F202', 'R305'],
#        ['Y2-DE3-PCRa', '051118_Unindexed', 'F203', 'R305'],
#        ['Y2-DE4-PCRa', '051118_Unindexed', 'F206', 'R305'],
#        ['Y3-DE1-PCRa', '040418_Unindexed', 'F208', 'R308'],
#        ['Y3-DE1-PCRa', '051118_Unindexed', 'F208', 'R308'],
#        ['Y4-DE1-PCRa', '051118_Unindexed', 'F202', 'R306'],
#        ['Y4-DE1-PCRb', '051118_Unindexed', 'F208', 'R307'],
#        ['Y4-DE2-PCRa', '051118_Unindexed', 'F210', 'R307'],
#        ['Y4-DE3-PCRa', '051118_Unindexed', 'F202', 'R307'],
#        ['Y4-DE4-PCRa', '051118_Unindexed', 'F203', 'R307'],
#        ['Z0-DE1-PCRa', '051118_Unindexed', 'F207', 'R302'],
#        ['Z0-DE2-PCRa', '051118_Unindexed', 'F204', 'R303'],
#        ['Z1-DE1-PCRa', '051118_Unindexed', 'F205', 'R308'],
#        ['Z2-DE1-PCRa', '051118_Unindexed', 'F207', 'R305'],
#        ['Z2-DE1-PCRb', '051118_Unindexed', 'F209', 'R304'],
#        ['Z2-DE2-PCRa', '051118_Unindexed', 'F211', 'R305'],
#        ['Z3-DE1-PCRa', '051118_Unindexed', 'F209', 'R308'],
#        ['Z4-DE1-PCRa', '051118_Unindexed', 'F204', 'R307'],
#        ['Z4-DE2-PCRa', '051118_Unindexed', 'F205', 'R307'],
#        ['B3-DE1-PCRa', '040418_Unindexed', 'F201', 'R301'],
#        ['B3-DE1-PCRa', '051118_Unindexed', 'F201', 'R301'],
#        ['B3-DE1-PCRa', '080618_Nextseq_N727S522', 'F210', 'R308'],
#        ['B3-DE1-PCRa', '082818_Hiseq_N727S522', 'F210', 'R308'],
#        ['B3-DE1-PCRa', '070418_diagonal_N727S522', 'F210', 'R308'],
#        ['C1-DE1-PCRa', '051118_Unindexed', 'F203', 'R308'],
#        ['C1-DE1-PCRa', '080618_Nextseq_N728S522', 'F211', 'R308'],
#        ['C1-DE1-PCRa', '082818_Hiseq_N728S522', 'F211', 'R308'],
#        ['Y1-DE1-PCRa', '051118_Unindexed', 'F204', 'R308'],
#        ['Y1-DE1-PCRa', '080618_Nextseq_N729S522', 'F212', 'R308'],
#        ['Y1-DE1-PCRa', '082818_Hiseq_N729S522', 'F212', 'R308']],
#       dtype=object)
